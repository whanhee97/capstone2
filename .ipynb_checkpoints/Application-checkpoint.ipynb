# %% [markdown]
# # 리뷰데이터 추가

# %%
import pandas as pd
from pandas import DataFrame  as df
import numpy as np
from collections import Counter
from konlpy.tag import Okt
okt = Okt()
# %matplotlib inline
import matplotlib.pyplot as plt
import re 
from datetime import datetime
import tomotopy as tp


data = pd.read_excel('reviews_youngtong.xlsx')

# %% [markdown]
# # 메뉴 검색(지역 주민이 고려하는 것)

# %%
user_input = input("메뉴를 검색하세요 : ")


arr = []

for i in range(len(data['메뉴'])):
    if type(data['메뉴'][i]) == str and user_input in data['메뉴'][i]:
        arr.append(data.loc[i])
        

searched_reviews = pd.DataFrame(arr, columns = ['지점명','유저','메뉴','리뷰','총점','맛','양','배달','시간'])



# 데이터 프레임의 '리뷰' 열의 값들을 str 형식으로 바꾸기
searched_reviews.리뷰 = searched_reviews.리뷰.astype(str)

# 중복데이터 삭제
searched_reviews.drop_duplicates(subset=['리뷰'],inplace=True)

# 한글이 아니면 빈 문자열로 바꾸기
searched_reviews['리뷰'] = searched_reviews['리뷰'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# 빈 문자열 NAN 으로 바꾸기
searched_reviews = searched_reviews.replace({'': np.nan})
searched_reviews = searched_reviews.replace(r'^\s*$', np.nan, regex=True)

# NAN 이 있는 행 삭제
searched_reviews.dropna(how='any', inplace=True)

# 인덱스 차곡차곡
searched_reviews = searched_reviews.reset_index (drop = True)


# 리뷰 데이터를 리스트로 변환
Data_list = searched_reviews.리뷰.values.tolist()
# 정규화 처리
Data_list = list(map(okt.normalize,Data_list))



# 명사,형용사 추출
data_word = []

# 한글자 짜리는 모두 없애야 함
stopword = ['같다','이다','있다','여기','항상','완전','정말','너무','보고','오늘','역시','이번','다음','아주']

for i, document in enumerate(Data_list):
    clean_words = []
    for word in okt.pos(document, stem=True): #어간 추출
        if word[1] in ['Noun','Adjective']: 
            if len(word[0]) >= 2 and word[0] not in stopword:
                clean_words.append(word[0])    
    data_word.append(clean_words)
    
    
def compute_coherence_values(data_word ,limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = tp.LDAModel(k=num_topics, alpha=0.1, eta=0.01, min_cf=20,tw=tp.TermWeight.PMI, rm_top=1)
        for i, line in enumerate(data_word):
            if not line:
                line.append(" ")
            model.add_doc(line)
        model.train(1500) # 학습 정도
        model_list.append(model)
        coherence_model = coherence.Coherence(model, coherence='c_v', window_size=0, targets=None, top_n=10, eps=1e-12, gamma=1.0)
        coherence_values.append(coherence_model.get_score())
    return model_list, coherence_values


# 토픽 수를 14~ 25 로 해서 각각의 모델과 일관성 점수를 계산한 리스트 얻기 
from tomotopy import coherence
model_list, coherence_values = compute_coherence_values(data_word=data_word, start=14, limit=25, step=2)


# 최적의 모델 얻기
limit=25; start=14; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
print()
print("=====================일관성 계산 결과======================")

for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

# 최적의 모델
optimal_model = model_list[model_list_num]


# 주제 단어 후보군 뽑기
extractor = tp.label.PMIExtractor(min_cf=15, min_df=5,min_len = 2, max_len=20, max_cand=10000)
cands = extractor.extract(optimal_model)

labels_per_topic = []

labeler = tp.label.FoRelevance(optimal_model, cands, min_df=5, smoothing=0.01, mu=0.25)
print()
print("=====================추출된 토픽======================")
for k in range(optimal_model.k):
    print("== Topic #{} ==".format(k))
    print("Labels:", ', '.join(label for label, score in labeler.get_topic_labels(k, top_n=5)))
    labels_per_topic.append(labeler.get_topic_labels(k, top_n=2)[0][0]+' + '+labeler.get_topic_labels(k, top_n=2)[1][0])
    for word, prob in optimal_model.get_topic_words(k, top_n=10):
        print(word, prob, sep='\t')
    print()
    
    
def format_topics_sentences(ldamodel=optimal_model):
    new_doc = ldamodel.docs
    sent_topics_df = pd.DataFrame()
    
    for i in range(len(data_word)):
        topics = new_doc[i].get_topics()
        for j, (topic_num, prop_topic) in enumerate(topics):
            if j == 0:
                wp = optimal_model.get_topic_words(topic_num, top_n=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                topic_label = labels_per_topic[topics[j][0]]
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4),topic_label, topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution','Topic_Label', 'Topic_Keywords']
    sent_topics_df = pd.concat([sent_topics_df, searched_reviews['지점명'],searched_reviews['유저'],searched_reviews['메뉴'],searched_reviews['리뷰'],searched_reviews['총점'],searched_reviews['맛'],searched_reviews['양'],searched_reviews['배달'],searched_reviews['시간']], axis=1)
    
    return(sent_topics_df) 


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model)
df_topic_review = df_topic_sents_keywords.reset_index()
df_topic_review.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib','Topic_Label' ,'Keywords', '지점명','유저', '메뉴','리뷰','총점','맛','양','배달','시간' ]
df_topic_review

# 토픽별 리뷰수
element_count = {}
for row in df_topic_review.iloc:
    element_count.setdefault(row['Dominant_Topic'],0)
    element_count[row['Dominant_Topic']]+=1

# 토픽별 총점 합계
topic_total = {}
for row in df_topic_review.iloc:
    topic_total.setdefault(row['Dominant_Topic'],0)
    topic_total[row['Dominant_Topic']]+=row['총점']

# 토픽별 평균 총점    
for topic in topic_total:
    topic_total[topic] = topic_total[topic] / element_count[topic]
topic_total


# 평균 별점 순으로 정렬
sdict= sorted(topic_total.items(), key= lambda x : x[1],reverse = True)


result = pd.DataFrame()
for i in range(3):
    topic = int(sdict[i][0])
    score = round(sdict[i][1],4)
    res = optimal_model.get_topic_words(topic, top_n=10)
    label = labels_per_topic[topic]
    keywords = ', '.join(w for w, p in res)
    result = result.append(pd.Series([topic, label,keywords, score]), ignore_index=True)
result.columns = ['Topic_num', 'Topic_name','Keywords','Score']


print()
print("=====================결과======================")
print()
print("영통 주민들이 << {} >>를 시킬때 고려하는 것".format(user_input))
result
# Out:
# 메뉴를 검색하세요 : 짜장
#
# =====================일관성 계산 결과======================
# Num Topics = 14  has Coherence Value of 0.5350377301020282
# Num Topics = 16  has Coherence Value of 0.5435796621255576
# Num Topics = 18  has Coherence Value of 0.532650276935763
# Num Topics = 20  has Coherence Value of 0.530063804090023
# Num Topics = 22  has Coherence Value of 0.5325206689536572
# Num Topics = 24  has Coherence Value of 0.5236045934880772
#
# =====================추출된 토픽======================
# == Topic #0 ==
# Labels: 짬뽕 국물, 차돌 짬뽕, 진짜 맛있다, 짜장 짬뽕, 짜장 소스
# 짬뽕	0.03819144517183304
# 탕수육	0.03505537286400795
# 짜장	0.03410447761416435
# 많다	0.03008469007909298
# 짜장면	0.028170477598905563
# 주문	0.027027051895856857
# 없다	0.025977004319429398
# 간짜장	0.025405146181583405
# 좋다	0.02459040842950344
# 처음	0.022782929241657257
#
# == Topic #1 ==
# Labels: 탕수육 고기, 맛있다 탕수육, 진짜 맛있다, 짬뽕 국물, 맛있다 짜장면
# 탕수육	0.19666631519794464
# 고기	0.15484119951725006
# 별로	0.13634610176086426
# 튀김	0.12397678196430206
# 찹쌀	0.11088305711746216
# 진짜	0.07213860005140305
# 짜장면	0.062130752950906754
# 짬뽕	0.05222358554601669
# 느낌	0.04851856827735901
# 괜찮다	0.017821934074163437
#
# == Topic #2 ==
# Labels: 포장 깔끔하다, 맛있다 탕수육, 배달 빠르다, 차돌 짬뽕, 진짜 맛있다
# 음식	0.18912655115127563
# 빠르다	0.1597018986940384
# 배달	0.15708209574222565
# 깔끔하다	0.12352617084980011
# 포장	0.1075618714094162
# 좋다	0.09057782590389252
# 전화	0.07220986485481262
# 주문	0.05734781548380852
# 자장면	0.0411873459815979
# 만두	2.953846524178516e-05
#
# == Topic #3 ==
# Labels: 양도 많다, 맛있다 양도, 양도 많다 맛있다, 많다 맛있다, 배달 빨르다
# 많다	0.17510771751403809
# 배달	0.16317717730998993
# 양도	0.15338052809238434
# 빨르다	0.12959924340248108
# 빠르다	0.1081773191690445
# 좋다	0.0857347771525383
# 자주	0.06833545118570328
# 생각	0.053487811237573624
# 음식	0.025636494159698486
# 포장	0.024711208418011665
#
# == Topic #4 ==
# Labels: 짬뽕 국물, 차돌 짬뽕, 진짜 맛있다, 짜장 짬뽕, 짜장면 맛있다
# 떡볶이	0.015191782265901566
# 탕수육	0.015189615078270435
# 배달	0.01516649965196848
# 짜장면	0.01515638642013073
# 없다	0.01515638642013073
#  	0.015154941007494926
# 시간	0.01515458058565855
# 짜장	0.0151542192324996
# 조금	0.015152773819863796
# 생각	0.015152773819863796
#
# == Topic #5 ==
# Labels: 배달 빨르다, 맛있다 짜장, 많다 맛있다, 양도 많다, 탕수육 진짜
# 빨르다	0.30697670578956604
# 진짜	0.18494167923927307
# 서비스	0.1570516973733902
# 배달	0.14313459396362305
# 좋다	0.11023502051830292
# 만두	0.06090332940220833
# 사진	0.03311832994222641
# 쟁반짜장	6.26088076387532e-05
# 짜장면	6.185626989463344e-05
# 주문	6.178866169648245e-05
#
# == Topic #6 ==
# Labels: 깔끔하다 맛있다, 탕수육 진짜, 진짜 맛있다, 짜장면 맛있다, 빠르다 맛있다
# 중국집	0.5758131146430969
# 제일	0.40979400277137756
# 없다	0.00023808557307347655
# 짜장면	0.00022734234516974539
# 차돌	0.00022701047419104725
# 고기	0.00022554646420758218
# 좋다	0.0002254474238725379
# 서비스	0.00022536178585141897
# 간짜장	0.00022520119091495872
# 처음	0.0002248586097266525
#
# == Topic #7 ==
# Labels: 맛있다 양도, 양도 많다, 양도 많다 맛있다, 많다 맛있다, 짜장 짬뽕
# 양도	0.2555820643901825
# 많다	0.1763230413198471
# 괜찮다	0.1612130105495453
# 좋다	0.1339692324399948
# 깔끔하다	0.08964090794324875
# 짜장면	0.08711200952529907
# 처음	0.0609799362719059
# 배달	0.03355572745203972
# 조금	2.8644662961596623e-05
# 국물	2.8483626010711305e-05
#
# == Topic #8 ==
# Labels: 맛있다 짜장, 짜장 짬뽕, 짜장 소스, 탕수육 고기, 탕수육 진짜
# 떡볶이	0.6676569581031799
# 짜장	0.3261649012565613
# 괜찮다	0.00010032828140538186
# 자주	9.735108324093744e-05
# 해물	9.684070391813293e-05
# 주문	9.664299432188272e-05
# 바삭	9.66337975114584e-05
# 배달	9.660620708018541e-05
# 서비스	9.65832150541246e-05
# 깔끔하다	9.657862392487004e-05
#
# == Topic #9 ==
# Labels: 진짜 맛있다, 탕수육 진짜, 맛있다 탕수육, 짬뽕 맛있다, 탕수육 맛있다
# 시간	0.19166693091392517
# 자장면	0.11544767767190933
# 불어	0.10455480217933655
# 탕수육	0.08998876810073853
# 맛집	0.08728112280368805
# 좋다	0.08026310056447983
# 주문	0.07500965893268585
# 진짜	0.0695044994354248
# 배달	0.06869309395551682
# 빨르다	0.05456918105483055
#
# == Topic #10 ==
# Labels: 양도 많다 맛있다, 탕수육 소스, 맛있다 양도, 탕수육 고기, 탕수육 진짜
#  	0.9967188239097595
# 양도	5.564563980442472e-05
# 깔끔하다	5.3216193919070065e-05
# 포장	5.056588997831568e-05
# 살짝	5.041945041739382e-05
# 정도	5.041224721935578e-05
# 빠르다	5.0378639571135864e-05
# 시간	5.037143637309782e-05
# 배달	5.036303628003225e-05
# 중국집	5.0359434681013227e-05
#
# == Topic #11 ==
# Labels: 짜장 짬뽕, 짜장 소스, 짜장면 맛있다, 탕수육 바삭, 맛있다 짜장
# 소스	0.15285538136959076
# 부족하다	0.12826605141162872
# 짜장	0.1077914834022522
# 탕슉	0.08108095824718475
# 탕수육	0.07394728064537048
# 느낌	0.06897202134132385
# 냄새	0.06378816813230515
# 배기	0.058622460812330246
# 짜장면	0.054721467196941376
# 고기	0.05365370959043503
#
# == Topic #12 ==
# Labels: 짬뽕 국물, 짜장 짬뽕, 탕수육 소스, 진짜 맛있다, 짜장 소스
# 조금	0.10531707108020782
# 없다	0.09782430529594421
# 전화	0.09193672239780426
# 사진	0.08946894854307175
# 짬뽕	0.07783211022615433
# 탕수육	0.07699901610612869
# 짜장	0.07077635824680328
# 국물	0.06923168897628784
# 주문	0.06295260041952133
# 소스	0.06102239340543747
#
# == Topic #13 ==
# Labels: 배달 빠르다, 빠르다 맛있다, 배달 빠르다 맛있다, 양도 많다, 많다 맛있다
# 빠르다	0.3487933278083801
# 배달	0.2982747554779053
# 친절하다	0.1196535974740982
# 좋다	0.09887686371803284
# 최고	0.06421147286891937
# 탕수육	0.03666858747601509
# 제일	0.020165324211120605
# 탕슉	0.012498058378696442
# 서비스	1.6559592040721327e-05
# 만두	1.6258982213912532e-05
#
# == Topic #14 ==
# Labels: 차돌 짬뽕, 짬뽕 맛있다, 배달 빠르다, 맛있다 짜장면, 배달 빨르다
# 최고	0.41201135516166687
# 짬뽕	0.1789923906326294
# 탕슉	0.17188505828380585
# 차돌	0.08426031470298767
# 자장면	0.0637471154332161
# 탕수육	0.043469324707984924
# 짜장	0.0427238903939724
# 괜찮다	5.0005317461909726e-05
# 짜장면	4.9869569920701906e-05
# 찹쌀	4.9751448386814445e-05
#
# == Topic #15 ==
# Labels: 포장 깔끔하다, 짬뽕 국물, 깔끔하다 맛있다, 차돌 짬뽕, 맛있다 짜장
# 깔끔하다	0.25281399488449097
# 국물	0.1947375237941742
# 포장	0.1871965080499649
# 짬뽕	0.17946617305278778
# 좋다	0.12532258033752441
# 짜장	0.05767866224050522
# 짜장면	4.853729478782043e-05
# 조금	4.8093043005792424e-05
# 소스	4.724786049337126e-05
# 없다	4.682705912273377e-05
#
#
# =====================결과======================
#
# 영통 주민들이 << 짜장 >>를 시킬때 고려하는 것
#    Topic_num          Topic_name                                    Keywords  \
# 0       14.0      차돌 짬뽕 + 짬뽕 맛있다  최고, 짬뽕, 탕슉, 차돌, 자장면, 탕수육, 짜장, 괜찮다, 짜장면, 찹쌀
# 1       15.0     포장 깔끔하다 + 짬뽕 국물   깔끔하다, 국물, 포장, 짬뽕, 좋다, 짜장, 짜장면, 조금, 소스, 없다
# 2       10.0  양도 많다 맛있다 + 탕수육 소스    , 양도, 깔끔하다, 포장, 살짝, 정도, 빠르다, 시간, 배달, 중국집
#
#     Score
# 0  4.8966
# 1  4.8750
# 2  4.8611

# %% [markdown]
# # 음식점 검색

# %% [markdown]
# ## 음식점 리스트

# %%
element_count = {}

for item in data['지점명']:
    element_count.setdefault(item,0)
    element_count[item] += 1
    
list(element_count.keys())
# Out:
# ['후라이드참잘하는집-영통흥덕점',
#  '피자헛-영통로점',
#  '김준현의피자헤븐-수원영통점',
#  '호식이두마리치킨-영통1호점',
#  'BBQ-용인서천점',
#  '롯데리아-수원영통점',
#  '미스터피자-영통점',
#  'PB델리-수원경희대점',
#  '아웃백-동탄반송점',
#  '파파존스피자-영통점',
#  '쫄면주는삼겹본능by놀부-수원망포점',
#  '에그드랍-영통역점',
#  '공차-수원영통점',
#  '원할머니보쌈-수원광교배달점',
#  '놀부보쌈족발-수원영통점',
#  '부어치킨-광교호수공원점',
#  '놀부부대찌개-수원영통점',
#  '맘스터치-수원경희대점',
#  '세븐일레븐-영통매영로점',
#  '호치킨-용인흥덕점',
#  '돈까스퐁당떡볶이공수간-수원망포점',
#  '두마리찜닭두찜-용인한보라점',
#  '족보잇는국밥&밀면-수원영통점',
#  '마약보쌈족발-서천점',
#  '맥도날드-경희대국제캠퍼스점',
#  '마싰는끼니-기흥서천점',
#  '카페인중독-수원영통점',
#  '반올림피자샵-영통점',
#  'KFC-영통씨네마점',
#  '제육대가-영통점',
#  '프랑킨숯불양념구이치킨-망포점',
#  '쏘자토스트-영통점',
#  '초밥쟁이',
#  '우쿠야-영통점',
#  '생생직판장',
#  '롯데리아-용인보라점',
#  '정성이가득찬집밥-영통점',
#  '뱃살도둑샐러드&과일-영통점',
#  '용인백암순대국왕뼈감자탕',
#  '혜경궁',
#  '석천칡냉면-영통점',
#  '덮밥90도씨-수원영통점',
#  '중앙왕족발보쌈',
#  '보배반점-수원영통점',
#  '야미가',
#  '떡순튀-망포영통점',
#  '해를품은짬뽕-용인점',
#  '배터지는생동까스-신구갈점',
#  '대만족동탄',
#  '또야지',
#  '싸움의고수-수원영통점',
#  '리얼베트남쌀국수&월남쌈-본점',
#  '던킨-영통홈플러스점',
#  '미챠이-경희대점',
#  'BBQ-수원망포점',
#  '요녀석파스타&필라프-영통점',
#  '중평떡볶이24시',
#  '커피브라더-영통점',
#  '청년다방-용인기흥역점',
#  '카페페리스휠',
#  '푸라닭-수원영통1호점',
#  '이디야커피-수원경희대점',
#  '진구네간장게장',
#  '백암왕순대왕뼈감자탕',
#  '단향',
#  '쭈대가-영통점',
#  '야미마라탕-경희대점',
#  '피자어셈블-영통서천점',
#  '미쳐버린파닭-경희대점',
#  '요거프레소-영통점',
#  '미스터짬뽕-영통2호점',
#  '탐앤탐스-수원경희대점',
#  "금커피별빙수'과일'영통점",
#  '봉구가래떡볶이-영통점',
#  '아이센스&쿡-수원경희대점',
#  'PB델리-영통뉴월드점',
#  '테그42-영통점',
#  '포한끼',
#  '혼밥대왕-영통점',
#  '응급실국물떡볶이-영통점',
#  'PB델리-영통중앙점',
#  '스쿨푸드-영통점',
#  '포1040-수원점',
#  '순둥이네손두부',
#  '뿅가야채곱창-수원매탄점',
#  '가본',
#  '소문난장충동왕족발보쌈',
#  '피자알볼로-영통점',
#  '남바완돈카츠',
#  '메콩타이-영통점',
#  '김충기꽃삼겹-수원영통점',
#  '본도시락-수원영통점',
#  '피자탑-수원영통점',
#  '업텐브로피자-수원영통점',
#  '귀한족발-수원영통점',
#  '푸라닭-용인서천지구점',
#  '깨봉이국물떡볶이-신갈점',
#  '참치잡는날-기흥점',
#  '감성낙곱새-수원점',
#  '배스킨라빈스-수원경희대점',
#  '떡슐랭-아주대점',
#  '백청우칼국수-영통점',
#  '꽃찬찜닭&등뼈찜-영통경희대점',
#  '냉면장인임사부-영통점',
#  '착한낙지-영통점',
#  '마시내탕수육-영통점',
#  '신떡순신천할매떡볶이-용인상갈보라점',
#  '땅스부대찌개-구갈점',
#  '셀렉토커피-동탄성심병원점',
#  '피자마루-영통신나무점',
#  '설빙-수원망포점',
#  '배스킨라빈스-용인서천점',
#  '스시몽-기흥점',
#  '마약낙곱새-기흥점',
#  '배스킨라빈스-영통홈플러스점',
#  '냉면쟁이고기꾼-경기수원영통점',
#  '리틀꼬마김밥-영통점',
#  '꽃찬등뼈찜-영통경희대점',
#  '배달삼겹돼지되지-영통점',
#  '써브웨이-수원경희대점',
#  '남도술상-신영통점',
#  '이화수육개장-영통원천점',
#  '데이비드커피랩',
#  '롯데리아-롯데마트영통점',
#  '삼성대반점',
#  '테트리스찜닭-영통점',
#  '삼첩분식-경기기흥점',
#  '응급실국물닭볶음탕-영통점',
#  '육회독존-영통점',
#  '고봉민김밥-수원영통점',
#  '서천쭈돈',
#  '바르다김선생-영통역점',
#  '구구족-영통역점',
#  '카페앤',
#  '환이네뭉티기-영통본점',
#  '제주흑돼지돈가츠가츠맘-영통점',
#  '오븐과치킨',
#  '셀렉토커피-화성반월점',
#  '오늘도닭갈비-영통동점',
#  '황포쭈꾸미-보라점',
#  '디델리-영통점',
#  '제육의신神-소담식당망포점',
#  '유로코피자-기흥점',
#  '더벤티-영통중앙점',
#  '설악칡냉면-신구갈점',
#  '닭zip순살치킨전문점',
#  '버텍스미국식덮밥-영통점',
#  '달리는커피-디저트',
#  '강릉동화가든짬뽕순두부-용인점',
#  '백종원의역전우동&덮밥-영통역점',
#  '무봉리토종순대국',
#  '국제왕돈가스&찌개&냉면',
#  '메가MGC커피-수원영통역점',
#  '참진숯불바베큐',
#  '장모님이떴다-용인점',
#  '조이포-보라점',
#  'WOW뉴욕피자',
#  '고기비비고쓱싹비빔밥-신갈점',
#  '김바비네김밥&떡볶이',
#  '신전떡볶이-화성서천점',
#  '511브레드타운',
#  '이마트24-용인서천마을점',
#  '디ㆍ델리&돈까스',
#  '커피에반하다-강남대점',
#  '알찜을아구아구-본점',
#  '커피나무-영통점',
#  '핵밥-수원망포점',
#  '불맛나면돼지직화막창곱창-영통점',
#  '마포족발&빈대떡',
#  '찬스불고기부리또-영통점',
#  '공차-홈플러스영통점',
#  '담이돈-돼지국밥&순대국전문점',
#  '골라먹는덮밥&냉면-수원영통점',
#  '일미돈가스',
#  '중평떡볶이24시본점',
#  '이삭토스트-수원경희대점',
#  '크로앙쥬-영통점',
#  '마피아떡볶이-신갈점',
#  '애슐리딜리버리-수원망포점',
#  '에그드랍-용인기흥구청점',
#  '청담아구찜해물찜-영통점',
#  '벌떡떡볶이-수원영통점',
#  '라메이즈마라탕-영통점',
#  '전티마이베트남쌀국수-망포점',
#  '디델리매콤라볶이',
#  '옳은고기',
#  '다이스피자',
#  '땅스부대찌개-영통점',
#  '작은콩카페',
#  '못난이꽈배기-용인기흥역점',
#  '행컵-영통점',
#  '악어토스트&커피-영통점',
#  '홍대감김치찜&두루치기',
#  '더벤티-용인흥덕점',
#  '오지게먹게-영통점',
#  '할매김치찜-용인점',
#  '홈플러스익스프레스-수원신영통점',
#  '안주사랑-반월점',
#  '지호한방삼계탕-영통점',
#  '꾸이한끼-수원영통점',
#  '두가지떡볶이-수원영통점',
#  '본죽-용인서천점',
#  '본죽-수원영통점',
#  '본죽-수원경희대점',
#  '하오츠-영덕점',
#  '긱스피자-기흥점',
#  '요거트아이스크림의정석-영통점',
#  '찜닭삼매경',
#  '리조또떡볶이리조떡-수원영통점',
#  '촌돼지쉐프',
#  '한끼한죽-영통점',
#  '라벤치파스타&스테이크-영통점',
#  '도요대창닭발',
#  '겐코-아주대점',
#  '장안통닭-광교직영점',
#  '백담김치찜',
#  '호아면-황골점',
#  '나는밥조폭이다-수원삼성점',
#  '치교치밥-영통점',
#  '충만치킨-망포점',
#  '베트남쌀국수포포&월남쌈',
#  '망원동티라미수-수원망포점',
#  '소담만두여행',
#  '수제돈까스가츠맘',
#  '에그타르트&캔커피는에그맛있다',
#  '보드람치킨-기흥구갈점',
#  '덮덮밥-수원영통점',
#  '에그드랍-광교상현역점',
#  '봉구스밥버거-경희대점',
#  '북촌손만두-기흥테라타워점',
#  '1인용이태원부대찌개-수원영통점',
#  '떡군이네떡볶이-영통점',
#  '국수나무-영통점',
#  '찌개공방-동탄점',
#  '장수촌',
#  '샤브향-수원영통점',
#  '육회통큰비빔밥-용인기흥점',
#  '카츠야미-신갈점',
#  '본스시-기흥점',
#  '설빙-경기용인보라점',
#  '1인육해공나혼자먹는다-동탄병점점',
#  '샛뿔추어탕',
#  '덮덮밥-경기기흥점',
#  '필라프에빠지다&파스타-수원매탄점',
#  '삼포가는길',
#  '부뚜막고기듬뿍',
#  '명인순대국-본점',
#  '올림커리with파스타',
#  '1인한식당-기흥점',
#  '혼밥에빠지다-영통점',
#  '해를품은짬뽕-화성반월점',
#  '베트남노상식당-망포영통점',
#  '금동양꼬치-영통점',
#  '백종원의한신포차-아주대점',
#  '달리는커피-수원영통점',
#  '배부장찌개-망포점',
#  '에그셀런트-기흥구청점',
#  '홍익스테이크-영통점',
#  '이돌박이',
#  '최고의만두-신갈본점',
#  '라투-영통본점',
#  '셀렉트카페&디저트',
#  '정성돈가스-영통점',
#  '동대문엽기떡볶이-용인보라점',
#  '장어명가섬진강',
#  '찐돈가스',
#  '듬박이김치찌개-흥덕점',
#  '강릉동화가든&꼬막이닭',
#  '영통닭발즉석떡볶이',
#  '1인불향쭈꾸미&낙지-동탄점',
#  '마라홀릭마라탕',
#  '달리는커피-샐러드',
#  '정성일인분-영통점',
#  '신당동즉석떡볶이FoodLab108',
#  '마카롱&디저트',
#  '달리는커피-샌드위치',
#  '김충기꽃삼겹-구갈점',
#  '조선닭볶음탕-수원영통점',
#  'USA존슨부대찌개-영통점',
#  '통큰고기통큰비빔밥-용인기흥점',
#  '도산분식-앨리웨이광교점',
#  '김밥나라-구갈점',
#  '달리는커피-그릴토스트',
#  '인계동떡슐랭',
#  '감탄떡볶이-신갈점',
#  '원조춘천닭갈비-기흥반도체점',
#  '팔미낙지한덮밥&왕아구찜',
#  '위캔커피',
#  '바르다김선생-광교상현점',
#  '땅스부대찌개-용인흥덕점',
#  '안성깍두기-영통점',
#  '냉면덕후-기흥점',
#  '1인용마라탕-수원영통점',
#  '미스터아구왕&탱고알찜-강남대점',
#  '타이테라스',
#  '텐퍼센트-동탄삼성반도체지점',
#  '쌀똑핫도그-용인기흥역점',
#  '오와스시-망포점',
#  '샌두-수원영통점',
#  '바르다김선생-기흥농서점',
#  '남도복국-기흥점',
#  '혼밥본가-영통점',
#  '마조치킨-동탄직영본점',
#  '카페선라이즈',
#  '오늘도만찬-영통점',
#  '광교떡슐랭',
#  '맛나면돈까스&마라탕',
#  '부두식당',
#  '킹콩부대찌개-AK기흥점',
#  '메가MGC커피-수원원천점',
#  '왕손피자-기흥점',
#  '에이그레이트카페-수원점',
#  '대박족발보쌈-수원광교점',
#  '에그박스-용인보라점',
#  '찌개엔-아주대점',
#  '쭈꾸미전문점안성깍두기-보라점',
#  '기흥숯불닭갈비&막국수',
#  '닐리비스트로-수원망포점',
#  '영통수산-본점',
#  '보글보글찌개나라-신영통점',
#  '수누리감자탕-망포점',
#  '달인의족발-망포역점',
#  '버무리떡볶이-용인신갈점',
#  '두리맛감자탕-흥덕점',
#  '1인용묵은지김치찜-수원영통점',
#  '샌드위치카페222',
#  '부함식당-수원망포역점',
#  '용피자-광교중흥점',
#  '집밥',
#  '덮앤고-영통점',
#  '아이캔커피-수원점',
#  '일복생선구이',
#  '뼈대있는국밥-기흥점',
#  '동해물과아구찜-기흥점',
#  '옥이네김치찌개와직화삼겹-수원매탄점',
#  '배달의태국',
#  '육육간-광교점',
#  '아미초밥',
#  '로고스탠드',
#  '콩이네손만두',
#  '태국음식배달맛집',
#  '쌀국수요기어때?',
#  '벌떡떡볶이-광교점',
#  '카페라이더-수원망포점',
#  '브라더탕수-광교점',
#  '유가네닭갈비-수원아주대점',
#  '동탄할매김치찜-용인동백점',
#  '스마일한식',
#  '미스터빅',
#  '삼돌박이-영통점',
#  '독도쭈꾸미-영통점',
#  '맵당-수원아주대점',
#  '엄마손맛푸드',
#  '바른소바',
#  '신수원화닭',
#  '싸움의고수-용인기흥역점',
#  '피자나라치킨공주-수원매탄점',
#  '사돌박이',
#  '치킨의민족-동탄점',
#  '프리미엄쫄면삼겹고돼지-아주대점',
#  '탐라카츠-광교본점',
#  '떡볶이의품격-수원매탄점',
#  '수원왕갈비통닭-광교흥덕영통점',
#  '미콩커피-아주대점',
#  '지성이해물찜-기흥점',
#  '더쉐프',
#  '청춘부추소곱창-동탄점',
#  '육회마니아',
#  '칠성식당',
#  '찹스테이크-수원직영점',
#  '자연담은가정식백반',
#  'GO집스테이크도시락-수원직영점',
#  '집스테이크-수원직영점',
#  '인생아구찜-수원점',
#  '바다향수산',
#  '찜과함께-수원점',
#  '청춘쭈꾸미-고매점',
#  '닭에꼬치닭-서천점',
#  '찜닭이땡기는날-매탄점',
#  'Sullivan&파스타&샐러드',
#  '그리니티',
#  '파라삼겹&짜글이',
#  '하랑중식당',
#  '유유식당',
#  '누룽지찜닭누찜-동탄점',
#  '오리촌-구갈점',
#  '벌교꼬막마당',
#  '꿀벌부대찌개',
#  '설화원-화성삼성점',
#  '버거킹-수원영통점',
#  '치킨플러스-수원영통점',
#  '두마리찜닭두찜-수원영통점',
#  '야들야들한보약족발보쌈-수원점',
#  '호식이두마리치킨-신영통점',
#  '빨강호랭이-영통점',
#  '멕시카나-신영통점',
#  '순수치킨-매탄점',
#  '웅이네오돌뼈닭발도-기흥점',
#  '맵짱떡볶이-아주대점',
#  '설빙-흥덕점',
#  '59쌀피자-용인서천점',
#  '오봉자싸롱-수원영통점',
#  '원할머니보쌈-영통점',
#  '청년피자-보라점',
#  '지구당-롯데마트영통점',
#  '맛닭꼬-영통점',
#  '제육불지존-광교상현점',
#  '설빙-수원영통점',
#  '요거프레소-수원삼성점',
#  '배스킨라빈스-수원영통역점',
#  '구이구이쪽갈비딜리버리',
#  '예원닭강정-영통점',
#  '티바두마리치킨-경희대점',
#  '봉구스밥버거-용인보라점',
#  '59쌀피자-매탄남부서점',
#  '큰맘할매순대국-수원영통점',
#  '해오름-경희대점',
#  '미스차차커피&샌드위치&샐러드',
#  '배달5삼겹-아주대점',
#  '네네치킨-영통1호점',
#  '떡볶이도맛있는치킨플러스-수원영통점',
#  '가리스시',
#  '곱덕후소곱창전문점',
#  '피아짜화덕피자',
#  '백종원의새마을식당-수원영통점',
#  '삼대족발-영통점',
#  '노랑통닭-용인보라점',
#  '엄마손시골밥상',
#  '가장맛있는족발-흥덕점',
#  '네네치킨-서천점',
#  '원조칡냉면',
#  '처갓집양념치킨-신영통점',
#  '다상참치-본점',
#  '멕시카나-매탄1점',
#  '이루카초밥',
#  '족발야시장-망포점',
#  '베스트생갈비찜&찜닭-기흥점',
#  '백종원의한신포차-수원영통점',
#  '푸라닭-용인기흥구청점',
#  '강씨가문의족발-공세점',
#  '가마로강정-기흥구청점',
#  '지코바치킨-반월1호점',
#  '돈치킨-구갈점',
#  '따신국밥-영통점',
#  '카페케이크(cafecake)디아망',
#  '피자선수-매탄남부서점',
#  'BHC-영통중앙점',
#  'RnBnoodle',
#  '육회천지-망포점',
#  '곱분이곱창-용인보라점',
#  '파스타입니다-영통점',
#  '지코바치킨-영통점',
#  '큰마루감자탕',
#  '부뚜막',
#  '뉴욕야시장-영통역점',
#  '반달커피-서천점',
#  '호치킨-수원영통청명마을점',
#  '페리카나-보라점',
#  '자담치킨-수원영통1점',
#  '아비꼬-흥덕유타워점',
#  '최배달떡순튀-기흥점',
#  '잇스토어',
#  '또또해물아구찜-기흥점',
#  '겐코-경희대점',
#  '피자나라치킨공주-수원영통점',
#  '돈갓수제돈까스-영통점',
#  '백강양꼬치훠궈',
#  '오늘도,카페일리터-수원영통점',
#  '피자와치킨의러브레터-수원망포영통점',
#  '도야족발-용인점',
#  '치킨마루-영덕점',
#  '월야-망포본점',
#  '시골칡냉면',
#  '육회한언니',
#  '바른마음족발-광교점',
#  '박사의알찜아구찜&1인분도배달OK',
#  '비잔틴-비빔밥&잔치국수전문점',
#  '이차돌-수원영통점',
#  '전골의법칙-수원영통점',
#  '마담타코야끼-신갈오거리점',
#  '돼지게티-영통점',
#  '야심찬곱창-신영통점',
#  '버무리떡볶이-서천점',
#  '아지트떡볶이',
#  '육회N연어-영통점',
#  '밥은화경희대국제캠퍼스점',
#  '착한참치상회',
#  '사탄곱창-구갈점',
#  '연어&육회',
#  '육회촌',
#  '허팔복가마솥족발',
#  '윙스버거-기흥역점',
#  '츄카롱&츄로아상-수원점',
#  '마초마초짬뽕火',
#  '참치야-구갈점',
#  '펀비어킹홈딜리버리-수원영통중앙점',
#  '김치찜1번가',
#  '이차돌-기흥서천점',
#  '왕관쓴돼지-영통점',
#  '샤브샵-본점',
#  '미스터빠삭-용인보라점',
#  '제주알찜-영통점',
#  '디아뜰리에',
#  '족발야시장-영통구청점',
#  '달보드레수제케잌',
#  '육감만족-동탄2신도시점',
#  '라벤치파스타&스테이크-본점',
#  '도야족발-아주대점',
#  '엄마찬',
#  '깻잎두마리치킨-망포서천점',
#  '만화고기',
#  '디커피',
#  '만원이닭-영통점',
#  '2012공세바로김밥',
#  '달곰쌀콤뚱스카롱',
#  '코리안바베큐-영통점',
#  '아주대순살두마리치킨',
#  '우주샐러드',
#  '명인만두-원천점',
#  '골뱅이매니아',
#  '가마치통닭-경기수원아주대점',
#  '리얼수제마카롱전문',
#  '곱가네순대곱창',
#  '1997그닭발-영통점',
#  '신단설렁탕-광교점',
#  '더꼬치다-아주대점',
#  '뚱뚱이장충동왕족발보쌈',
#  '라홍방마라탕-서천점',
#  '뚜레쥬르-기흥역점',
#  '떡보킹-기흥점',
#  '서천회포장전문점',
#  '밀포유-영통점',
#  '커피zip',
#  '투다리-서농점',
#  '계동원안동찜닭-본점',
#  '야들리애-원천점',
#  '강씨가문의족발-광교아주대점',
#  '브라보치킨피자-수원매탄점',
#  '그냥맛있는연탄생선구이',
#  '수원신닭발-반도체후문점',
#  '마조치킨-수원점',
#  '꽃남포차',
#  '홈런즉석떡볶이-A&K기흥점',
#  '택이네조개전골-보라점',
#  '대창X쭈꾸미쭈스타-신갈점',
#  '싱싱수산-기흥구청점',
#  '뿔닭빨',
#  '돈통마늘보쌈-매탄점',
#  '연정일식',
#  '호동이가마솥순대족발',
#  '수원참닭발',
#  '뚱보집부산양대창',
#  '막창클라쓰',
#  '스시유메-초밥전문점',
#  '경성함바그-AK기흥점',
#  '스시앤-기흥힉스점',
#  '맛담은족발&보쌈-영통점',
#  '성북동돈까스-강남대점',
#  '여주집',
#  '맛앤덤숯불바베큐',
#  '열정국밥-수원망포동점']

# %%
user_input = input("음식점을 검색하세요 : ")

arr = []

for i in range(len(data['지점명'])):
    if type(data['지점명'][i]) == str and user_input in data['지점명'][i]:
        arr.append(data.loc[i])
        

searched_reviews = pd.DataFrame(arr, columns = ['지점명','유저','메뉴','리뷰','총점','맛','양','배달','시간'])


# 데이터 프레임의 '리뷰' 열의 값들을 str 형식으로 바꾸기
searched_reviews.리뷰 = searched_reviews.리뷰.astype(str)

# 중복데이터 삭제
searched_reviews.drop_duplicates(subset=['리뷰'],inplace=True)

# 한글이 아니면 빈 문자열로 바꾸기
searched_reviews['리뷰'] = searched_reviews['리뷰'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# 빈 문자열 NAN 으로 바꾸기
searched_reviews = searched_reviews.replace({'': np.nan})
searched_reviews = searched_reviews.replace(r'^\s*$', np.nan, regex=True)

# NAN 이 있는 행 삭제
searched_reviews.dropna(how='any', inplace=True)

# 인덱스 차곡차곡
searched_reviews = searched_reviews.reset_index (drop = True)


# 리뷰 데이터를 리스트로 변환
Data_list = searched_reviews.리뷰.values.tolist()
# 정규화 처리
Data_list = list(map(okt.normalize,Data_list))



# 명사,형용사 추출
data_word = []

# 한글자 짜리는 모두 없애야 함
stopword = ['같다','이다','있다','여기','항상','완전','정말','너무','보고','오늘','역시','이번','다음','아주']

for i, document in enumerate(Data_list):
    clean_words = []
    for word in okt.pos(document, stem=True): #어간 추출
        if word[1] in ['Noun','Adjective']: 
            if len(word[0]) >= 2 and word[0] not in stopword:
                clean_words.append(word[0])    
    data_word.append(clean_words)
    
    
def compute_coherence_values(data_word ,limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = tp.LDAModel(k=num_topics, alpha=0.1, eta=0.01, min_cf=20,tw=tp.TermWeight.PMI, rm_top=1)
        for i, line in enumerate(data_word):
            if not line:
                line.append(" ")
            model.add_doc(line)
        model.train(1500) # 학습 정도
        model_list.append(model)
        coherence_model = coherence.Coherence(model, coherence='c_v', window_size=0, targets=None, top_n=10, eps=1e-12, gamma=1.0)
        coherence_values.append(coherence_model.get_score())
    return model_list, coherence_values


# 토픽 수를 14~ 25 로 해서 각각의 모델과 일관성 점수를 계산한 리스트 얻기 
from tomotopy import coherence
model_list, coherence_values = compute_coherence_values(data_word=data_word, start=14, limit=25, step=2)


# 최적의 모델 얻기
limit=25; start=14; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
print()
print("=====================일관성 계산 결과======================")

for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

# 최적의 모델
optimal_model = model_list[model_list_num]


# 주제 단어 후보군 뽑기
extractor = tp.label.PMIExtractor(min_cf=15, min_df=5,min_len = 2, max_len=20, max_cand=10000)
cands = extractor.extract(optimal_model)

labels_per_topic = []

labeler = tp.label.FoRelevance(optimal_model, cands, min_df=5, smoothing=0.01, mu=0.25)
print()
print("=====================추출된 토픽======================")
for k in range(optimal_model.k):
    print("== Topic #{} ==".format(k))
    print("Labels:", ', '.join(label for label, score in labeler.get_topic_labels(k, top_n=5)))
    labels_per_topic.append(labeler.get_topic_labels(k, top_n=2)[0][0]+' + '+labeler.get_topic_labels(k, top_n=2)[1][0])
    for word, prob in optimal_model.get_topic_words(k, top_n=10):
        print(word, prob, sep='\t')
    print()
    
    
def format_topics_sentences(ldamodel=optimal_model):
    new_doc = ldamodel.docs
    sent_topics_df = pd.DataFrame()
    
    for i in range(len(data_word)):
        topics = new_doc[i].get_topics()
        for j, (topic_num, prop_topic) in enumerate(topics):
            if j == 0:
                wp = optimal_model.get_topic_words(topic_num, top_n=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                topic_label = labels_per_topic[topics[j][0]]
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4),topic_label, topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution','Topic_Label', 'Topic_Keywords']
    sent_topics_df = pd.concat([sent_topics_df, searched_reviews['지점명'],searched_reviews['유저'],searched_reviews['메뉴'],searched_reviews['리뷰'],searched_reviews['총점'],searched_reviews['맛'],searched_reviews['양'],searched_reviews['배달'],searched_reviews['시간']], axis=1)
    
    return(sent_topics_df) 


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model)
df_topic_review = df_topic_sents_keywords.reset_index()
df_topic_review.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib','Topic_Label' ,'Keywords', '지점명','유저', '메뉴','리뷰','총점','맛','양','배달','시간' ]
df_topic_review

# 토픽별 리뷰수
element_count = {}
for row in df_topic_review.iloc:
    element_count.setdefault(row['Dominant_Topic'],0)
    element_count[row['Dominant_Topic']]+=1

# 토픽별 총점 합계
topic_total = {}
for row in df_topic_review.iloc:
    topic_total.setdefault(row['Dominant_Topic'],0)
    topic_total[row['Dominant_Topic']]+=row['총점']

# 토픽별 평균 총점    
for topic in topic_total:
    topic_total[topic] = topic_total[topic] / element_count[topic]
topic_total


# 평균 별점 순으로 정렬
sdict= sorted(topic_total.items(), key= lambda x : x[1],reverse = True)


result = pd.DataFrame()
for i in range(3):
    topic = int(sdict[i][0])
    score = round(sdict[i][1],4)
    res = optimal_model.get_topic_words(topic, top_n=10)
    label = labels_per_topic[topic]
    keywords = ', '.join(w for w, p in res)
    result = result.append(pd.Series([topic, label,keywords, score]), ignore_index=True)
result.columns = ['Topic_num', 'Topic_name','Keywords','Score']


print()
print("=====================결과======================")
print()
print("소비자들이 평가한 << {} >> 의 특징".format(user_input))
result
# Out:
# 음식점을 검색하세요 : 후라이드참잘하는집
#
# =====================일관성 계산 결과======================
# Num Topics = 14  has Coherence Value of 0.5902505061056997
# Num Topics = 16  has Coherence Value of 0.565648172062356
# Num Topics = 18  has Coherence Value of 0.5634347373205755
# Num Topics = 20  has Coherence Value of 0.5697247929126024
# Num Topics = 22  has Coherence Value of 0.5521489466159519
# Num Topics = 24  has Coherence Value of 0.5603062455697606
#
# =====================추출된 토픽======================
# == Topic #0 ==
# Labels: 예상 시간, 배달 예상 시간, 배달 예상, 양념 소스, 배달 시간
# 시간	0.08710204064846039
# 예상	0.06332171708345413
# 바삭	0.05766037851572037
# 배달	0.05551692098379135
# 후라이드	0.0504692867398262
# 간장	0.036472074687480927
# 매콤	0.03457072377204895
# 양념	0.03378007560968399
# 좋다	0.03322535753250122
# 치킨	0.029206683859229088
#
# == Topic #1 ==
# Labels: 맛있다 배달, 서비스 좋다, 빠르다 배달, 배달 빠르다, 예상 시간
# 배달	0.18901149928569794
# 빠르다	0.17753535509109497
# 좋다	0.06590453535318375
# 언제	0.060195744037628174
# 빨르다	0.056069012731313705
# 양은	0.03943304717540741
# 친절하다	0.0393812321126461
# 서비스	0.03911357372999191
# 요청	0.03779496252536774
# 배송	0.029695063829421997
#
# == Topic #2 ==
# Labels: 맵다 양념, 양념 후라이드, 맛있다 양념, 후라이드 양념, 진짜 맛있다
# 맵다	0.168338805437088
# 후라이드	0.15219919383525848
# 양념	0.10596279054880142
# 진짜	0.08776259422302246
# 적당하다	0.06689222902059555
# 이름	0.05601130425930023
# 치킨	0.04940347373485565
# 좋아하다	0.0435737706720829
# 간장	0.035476204007864
# 자주	0.035193875432014465
#
# == Topic #3 ==
# Labels: 하리보 젤리, 감자 튀김, 치킨 맛있다, 맛있다 얼음, 양념 소스
# 치킨	0.03540944308042526
# 서비스	0.032466620206832886
# 리뷰	0.03143209591507912
# 센스	0.029314298182725906
# 좋다	0.029164373874664307
# 하리보	0.028632089495658875
# 주문	0.02796974405646324
# 얼음	0.027079006657004356
# 소스	0.02551257610321045
# 젤리	0.022935541346669197
#
# == Topic #4 ==
# Labels: 양도 많다, 서비스 감자, 배달 빠르다, 감자 튀김, 리뷰 이벤트
# 많다	0.06904679536819458
# 양도	0.06308016180992126
# 추천	0.05587564781308174
# 좋다	0.05512944981455803
# 자주	0.05212656408548355
# 배달	0.04464117810130119
# 가성	0.042836420238018036
# 빠르다	0.041712988168001175
# 최고	0.03580336645245552
# 가격	0.0357762910425663
#
# == Topic #5 ==
# Labels: 굳다 굳다, 영통 흥덕, 배달 빠르다 좋다, 따뜻하다 맛있다, 후라이드 맛있다 양념
#  	0.997847318649292
# 추가	2.286517519678455e-05
# 물티슈	2.271826087962836e-05
# 많다	2.271069934067782e-05
# 감자	2.2705704395775683e-05
# 주문	2.2703678041580133e-05
# 바삭	2.26880147238262e-05
# 센스	2.268045318487566e-05
# 후라이드	2.2675321815768257e-05
# 배달	2.2669380996376276e-05
#
# == Topic #6 ==
# Labels: 양념 소스, 후라이드 간장, 양념 후라이드, 맵다 양념, 맛있다 후라이드
# 간장	0.07885187864303589
# 양념	0.06638888269662857
# 처음	0.04982658103108406
# 소스	0.04938353970646858
# 달달	0.04423623904585838
# 느낌	0.04091113060712814
# 양념치킨	0.039506975561380386
# 맵다	0.03942585363984108
# 그렇다	0.02975742518901825
# 후라이드	0.029377346858382225
#
# == Topic #7 ==
# Labels: 감자 튀김, 맛있다 감자 튀김, 튀김 맛있다, 서비스 감자, 감자 튀김 맛있다
# 감자	0.1100643053650856
# 튀김	0.10934298485517502
# 얼음	0.06789632886648178
# 이벤트	0.05868034064769745
# 리뷰	0.05819623917341232
# 콜라	0.05782197788357735
# 서비스	0.054748933762311935
# 치킨	0.053962342441082
# 배달	0.04801420867443085
# 빠르다	0.03423056751489639
#
# == Topic #8 ==
# Labels: 양도 많다, 많다 맛있다, 양도 많다 맛있다, 맛있다 양도 많다, 맛있다 양도
# 많다	0.257428914308548
# 양도	0.22596676647663116
# 사진	0.10748206824064255
# 좋다	0.07397788017988205
# 부드럽다	0.05549340322613716
# 없다	0.05296992138028145
# 마리	0.050392474979162216
# 진짜	0.04471820220351219
# 추천	0.03910378739237785
# 서비스	0.035603951662778854
#
# == Topic #9 ==
# Labels: 양념 후라이드, 양념 소스, 맛있다 양념, 리뷰 이벤트, 후라이드 양념
# 후라이드	0.1418645977973938
# 사진	0.09116701781749725
# 치킨	0.08631071448326111
# 최고	0.07775908708572388
# 존맛	0.07051485031843185
# 주문	0.06355059891939163
# 흥덕	0.05880460888147354
# 아니다	0.05596860125660896
# 양념	0.04302601143717766
# 제일	0.040151696652173996
#
# == Topic #10 ==
# Labels: 감자 튀김, 눈꽃 치즈, 서비스 주신, 후라이드 양념, 하리보 젤리
# 치즈	0.13685213029384613
# 눈꽃	0.13669098913669586
# 살이	0.12093617767095566
# 가슴	0.10131971538066864
# 부드럽다	0.07174708694219589
# 감자	0.055851105600595474
# 가루	0.05562255159020424
# 없다	0.05074479803442955
# 좋아하다	0.04735241085290909
# 별로	0.04612812027335167
#
# == Topic #11 ==
# Labels: 살짝 매콤, 바삭 맛있다, 양념 소스, 후라이드 간장, 양념 후라이드
# 후라이드	0.17034326493740082
# 매콤	0.15537896752357483
# 아이	0.15411992371082306
# 바삭	0.11687521636486053
# 살짝	0.10998149961233139
# 맵다	0.07737073302268982
# 먹기	0.06989936530590057
# 약간	0.05504335090517998
# 양념	0.051117874681949615
# 깔끔하다	0.014485510997474194
#
# == Topic #12 ==
# Labels: 맛있다 배달 빠르다, 후라이드 양념, 맛있다 배달, 감자 튀김, 배달 빠르다
# 최고	0.1569119542837143
# 가성	0.13927321135997772
# 좋다	0.09303320199251175
# 가격	0.08838514983654022
# 모두	0.07412267476320267
# 맛집	0.07388792186975479
# 치킨	0.06690314412117004
# 만족하다	0.059626076370477676
# 저렴하다	0.04154633730649948
# 후라이드	0.03787476196885109
#
# == Topic #13 ==
# Labels: 굳다 굳다, 맛있다 후라이드 맛있다, 소스 맛있다, 언제 맛있다, 맛있다 배달 빠르다
# 굳다	0.8959219455718994
# 가성	0.03985428065061569
# 서비스	0.025656946003437042
# 없다	0.01737237721681595
# 양념	0.016667993739247322
# 배달	5.513719224836677e-05
# 빠르다	5.0110731535824016e-05
# 많다	4.994734990759753e-05
# 바삭바삭하다	4.9888149078469723e-05
# 치킨	4.984316183254123e-05
#
#
# =====================결과======================
#
# 소비자들이 평가한 << 후라이드참잘하는집 >> 의 특징
#    Topic_num            Topic_name  \
# 0        8.0        양도 많다 + 많다 맛있다
# 1       13.0  굳다 굳다 + 맛있다 후라이드 맛있다
# 2        1.0       맛있다 배달 + 서비스 좋다
#
#                                        Keywords   Score
# 0     많다, 양도, 사진, 좋다, 부드럽다, 없다, 마리, 진짜, 추천, 서비스  4.9865
# 1  굳다, 가성, 서비스, 없다, 양념, 배달, 빠르다, 많다, 바삭바삭하다, 치킨  4.9231
# 2   배달, 빠르다, 좋다, 언제, 빨르다, 양은, 친절하다, 서비스, 요청, 배송  4.9116

# %% [markdown]
# ## 음식점의 아쉬운 점

# %%
searched_reviews = pd.DataFrame(arr, columns = ['지점명','유저','메뉴','리뷰','총점','맛','양','배달','시간'])
searched_reviews = searched_reviews[(searched_reviews.총점 <= 2)]

# 데이터 프레임의 '리뷰' 열의 값들을 str 형식으로 바꾸기
searched_reviews.리뷰 = searched_reviews.리뷰.astype(str)

# 중복데이터 삭제
searched_reviews.drop_duplicates(subset=['리뷰'],inplace=True)

# 한글이 아니면 빈 문자열로 바꾸기
searched_reviews['리뷰'] = searched_reviews['리뷰'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# 빈 문자열 NAN 으로 바꾸기
searched_reviews = searched_reviews.replace({'': np.nan})
searched_reviews = searched_reviews.replace(r'^\s*$', np.nan, regex=True)

# NAN 이 있는 행 삭제
searched_reviews.dropna(how='any', inplace=True)

# 인덱스 차곡차곡
searched_reviews = searched_reviews.reset_index (drop = True)


# 리뷰 데이터를 리스트로 변환
Data_list = searched_reviews.리뷰.values.tolist()
# 정규화 처리
Data_list = list(map(okt.normalize,Data_list))



# 명사,형용사 추출
data_word = []

# 한글자 짜리는 모두 없애야 함
stopword = ['같다','이다','있다','여기','항상','완전','정말','너무','보고','오늘','역시','이번','다음','아주','신랑','살후']

for i, document in enumerate(Data_list):
    clean_words = []
    for word in okt.pos(document, stem=True): #어간 추출
        if word[1] in ['Noun','Adjective']: 
            if len(word[0]) >= 2 and word[0] not in stopword:
                clean_words.append(word[0])    
    data_word.append(clean_words)
    
    
def compute_coherence_values(data_word ,limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = tp.LDAModel(k=num_topics, alpha=0.1, eta=0.01, min_cf=1,tw=tp.TermWeight.PMI, rm_top=1)
        for i, line in enumerate(data_word):
            if not line:
                line.append(" ")
            model.add_doc(line)
        model.train(500) # 학습 정도
        model_list.append(model)
        coherence_model = coherence.Coherence(model, coherence='c_v', window_size=0, targets=None, top_n=10, eps=1e-12, gamma=1.0)
        coherence_values.append(coherence_model.get_score())
    return model_list, coherence_values


# 토픽 수를 14~ 25 로 해서 각각의 모델과 일관성 점수를 계산한 리스트 얻기 
from tomotopy import coherence
model_list, coherence_values = compute_coherence_values(data_word=data_word, start=4, limit=21, step=2)


# 최적의 모델 얻기
limit=21; start=4; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
print()
print("=====================일관성 계산 결과======================")

for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

# 최적의 모델
optimal_model = model_list[model_list_num]


# 주제 단어 후보군 뽑기
extractor = tp.label.PMIExtractor(min_cf=1, min_df=1,min_len = 2, max_len=5, max_cand=10000)
cands = extractor.extract(optimal_model)

labels_per_topic = []

labeler = tp.label.FoRelevance(optimal_model, cands, min_df=1, smoothing=0.01, mu=0.25)
print()
print("=====================추출된 토픽======================")
for k in range(optimal_model.k):
    print("== Topic #{} ==".format(k))
    print("Labels:", ', '.join(label for label, score in labeler.get_topic_labels(k, top_n=5)))
    labels_per_topic.append(labeler.get_topic_labels(k, top_n=2)[0][0]+' + '+labeler.get_topic_labels(k, top_n=2)[1][0])
    for word, prob in optimal_model.get_topic_words(k, top_n=10):
        print(word, prob, sep='\t')
    print()
    
    
def format_topics_sentences(ldamodel=optimal_model):
    new_doc = ldamodel.docs
    sent_topics_df = pd.DataFrame()
    
    for i in range(len(data_word)):
        topics = new_doc[i].get_topics()
        for j, (topic_num, prop_topic) in enumerate(topics):
            if j == 0:
                wp = optimal_model.get_topic_words(topic_num, top_n=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                topic_label = labels_per_topic[topics[j][0]]
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4),topic_label, topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution','Topic_Label', 'Topic_Keywords']
    sent_topics_df = pd.concat([sent_topics_df, searched_reviews['지점명'],searched_reviews['유저'],searched_reviews['메뉴'],searched_reviews['리뷰'],searched_reviews['총점'],searched_reviews['맛'],searched_reviews['양'],searched_reviews['배달'],searched_reviews['시간']], axis=1)
    
    return(sent_topics_df) 


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model)
df_topic_review = df_topic_sents_keywords.reset_index()
df_topic_review.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib','Topic_Label' ,'Keywords', '지점명','유저', '메뉴','리뷰','총점','맛','양','배달','시간' ]
df_topic_review

# 토픽별 리뷰수
element_count = {}
for row in df_topic_review.iloc:
    element_count.setdefault(row['Dominant_Topic'],0)
    element_count[row['Dominant_Topic']]+=1

# 토픽별 총점 합계
topic_total = {}
for row in df_topic_review.iloc:
    topic_total.setdefault(row['Dominant_Topic'],0)
    topic_total[row['Dominant_Topic']]+=row['총점']

# 토픽별 평균 총점    
for topic in topic_total:
    topic_total[topic] = topic_total[topic] / element_count[topic]
topic_total


# 평균 별점 순으로 정렬
sdict= sorted(topic_total.items(), key= lambda x : x[1],reverse = True)


result = pd.DataFrame()
for i in range(3):
    topic = int(sdict[i][0])
    score = round(sdict[i][1],4)
    res = optimal_model.get_topic_words(topic, top_n=10)
    label = labels_per_topic[topic]
    keywords = ', '.join(w for w, p in res)
    result = result.append(pd.Series([topic, label,keywords, score]), ignore_index=True)
result.columns = ['Topic_num', 'Topic_name','Keywords','Score']


print()
print("=====================결과======================")
print()
print("소비자들이 평가한 << {} >> 의 아쉬운점".format(user_input))
result
# Out:
# =====================일관성 계산 결과======================
# Num Topics = 4  has Coherence Value of 0.7624119125306607
# Num Topics = 6  has Coherence Value of 0.826604950428009
# Num Topics = 8  has Coherence Value of 0.8537839680910111
# Num Topics = 10  has Coherence Value of 0.9001901179552079
# Num Topics = 12  has Coherence Value of 0.9060639346639313
# Num Topics = 14  has Coherence Value of 0.9138416456324715
# Num Topics = 16  has Coherence Value of 0.9086394879966975
# Num Topics = 18  has Coherence Value of 0.9000288056002722
# Num Topics = 20  has Coherence Value of 0.8939499065279962
#
# =====================추출된 토픽======================
# == Topic #0 ==
# Labels: 양념 뭍혀 후라이드 기름, 기름 오래되다, 후라이드 기름, 뭍혀 후라이드 기름, 기름 오래되다 튀김 냄새 양념
# 튀김	0.07932296395301819
# 아니다	0.07289432734251022
# 기름	0.06619047373533249
# 생각	0.061348967254161835
# 양념	0.05068545788526535
# 냄새	0.04872279614210129
# 마리	0.04425749182701111
# 양은	0.04313413426280022
# 심하다	0.041779547929763794
# 오래되다	0.04159277677536011
#
# == Topic #1 ==
# Labels: 모름 맛있다 연구 귀찮다 성공, 기본 모름 맛있다 연구 귀찮다, 프렌차이즈 이유 기본 모름 맛있다, 성공 리뷰 이벤트, 기본 프렌차이즈 이유 기본
# 기본	0.18941688537597656
# 프렌차이즈	0.09484768658876419
# 이유	0.09484768658876419
# 모름	0.09484768658876419
# 맛있다	0.09484768658876419
# 귀찮다	0.09484768658876419
# 성공	0.09484768658876419
# 이벤트	0.09484768658876419
# 답답하다	0.09484768658876419
# 아니다	0.0002785162068903446
#
# == Topic #2 ==
# Labels: 안나 살이 기고 형평 없엇, 뿌링 조금 안나, 형평 없엇 맛없다 조금, 간장 치토스 치즈 뿌링, 조금 안나 살이 기고 형평
# 치토스	0.16545461118221283
# 아프다	0.13531646132469177
# 가요	0.13531646132469177
# 없엇	0.08285747468471527
# 그거	0.08285747468471527
# 치즈	0.08285747468471527
# 형평	0.08285747468471527
# 맛없다	0.06525111198425293
# 조금	0.06481105834245682
# 맵다	0.054254576563835144
#
# == Topic #3 ==
# Labels: 이상하다 후라이드 간장, 안나 짠맛 일찍, 살짝 느낌 간장 소스, 이상하다 후라이드 간장 소스, 리뷰 괜찮다
# 간장	0.24695329368114471
# 소스	0.1501713991165161
# 안나	0.11741247773170471
# 살이	0.07520384341478348
# 살짝	0.07520384341478348
# 느낌	0.07520384341478348
# 짠맛	0.07520384341478348
# 일찍	0.07520384341478348
# 리뷰	0.0492430217564106
# 후라이드	0.016484113410115242
#
# == Topic #4 ==
# Labels: 좋다 없다 최악 대요 진짜, 대요 진짜 웬만하다, 진짜 웬만하다, 프랜차이즈 시킬껄 차량 대충 신건, 사람 그냥 프랜차이즈
# 대충	0.11611616611480713
# 진짜	0.09667529165744781
# 웬만하다	0.07629546523094177
# 남푠	0.07629546523094177
# 사람	0.07629546523094177
# 대요	0.07629546523094177
# 프랜차이즈	0.07629546523094177
# 시킬껄	0.07629546523094177
# 차량	0.07629546523094177
# 신건	0.07629546523094177
#
# == Topic #5 ==
# Labels: 그냥 그렇다, 저렴하다 주문 그냥, 쿠폰 저렴하다 주문 그냥, 저렴하다 주문, 쿠폰 저렴하다
# 그렇다	0.11961369216442108
# 그냥	0.10880561172962189
# 주문	0.10474182665348053
# 시간	0.10267966240644455
# 리뷰	0.09213076531887054
# 쿠폰	0.06166881322860718
# 저렴하다	0.06166881322860718
# 눅눅하다	0.06166881322860718
# 딱딱하다	0.06130329892039299
# 도안	0.053201790899038315
#
# == Topic #6 ==
# Labels: 딱딱하다 실망 절반 준비, 원래 좋아하다 그냥, 그냥 튀김 덩어리 그것, 덩어리 그것 딱딱하다 실망 절반, 튀김 덩어리 그것 딱딱하다
# 좋아하다	0.11130128055810928
# 거나	0.10334943979978561
# 부위	0.07134594023227692
# 둘째	0.07134594023227692
# 제일	0.07134594023227692
# 한참	0.07134594023227692
# 그것	0.06772049516439438
# 절반	0.06772049516439438
# 준비	0.06772049516439438
# 맥주	0.06772049516439438
#
# == Topic #7 ==
# Labels: 빨르다 조각 제대로 지도 상자, 지도 상자 크기 덩어리, 빨르다 조각 제대로, 덩어리 딱딱하다 없다, 조각 제대로 지도 상자 크기
# 배달	0.13137711584568024
# 빨르다	0.12750974297523499
# 제대로	0.06824088841676712
# 드림	0.05926968902349472
# 죄송하다	0.05926968902349472
# 상태	0.04713812842965126
# 먹기	0.04713812842965126
# 조각	0.044378139078617096
# 지도	0.044378139078617096
# 상자	0.044378139078617096
#
# == Topic #8 ==
# Labels: 갑자기 안좋다, 역류 심하다 장난, 쓰셧 역류 심하다, 안좋다 기름 쓰셧, 기름 쓰셧 역류 심하다
# 안좋다	0.1645807921886444
# 재료	0.10714083164930344
# 박스	0.10714083164930344
# 검은색	0.10714083164930344
# 무언가	0.10714083164930344
# 갑자기	0.09065315872430801
# 쓰셧	0.09065315872430801
# 역류	0.09065315872430801
# 장난	0.09065315872430801
# 후라이드	0.00023788934049662203
#
# == Topic #9 ==
# Labels: 처음 수입, 이렇다 없다, 기고 부드럽다 부분 별로, 부분 별로, 기고 부드럽다
# 라이드	0.13384801149368286
# 처음	0.11997956037521362
# 이렇다	0.11997956037521362
# 싫다	0.08356054872274399
# 신경	0.08356054872274399
# 주지	0.08356054872274399
# 수입	0.06703363358974457
# 냉동	0.06703363358974457
# 뻣뻣하다	0.06703363358974457
# 부드럽다	0.06703363358974457
#
# == Topic #10 ==
# Labels: 양념치킨 진짜 질겨, 신선하다 치킨 양념치킨 껍질, 치킨 아니다 기분 정도, 아마 신선하다 치킨 양념치킨, 질겨 치킨
# 치킨	0.08263148367404938
# 신선하다	0.0674135833978653
# 절대	0.046477802097797394
# 질겨	0.046477802097797394
# 양념치킨	0.046477802097797394
# 사용	0.045470427721738815
# 바람	0.045470427721738815
# 벼르	0.03525828197598457
# 왠만하다	0.03525828197598457
# 잔뜩	0.03525828197598457
#
# == Topic #11 ==
# Labels: 고기 퍽퍽 참나 짜증 대박, 대박 맛없다, 맛없다 고기 퍽퍽 참나, 고기 퍽퍽, 퍽퍽 참나
# 맛없다	0.17033758759498596
# 퍽퍽	0.14567555487155914
# 할인	0.09991785138845444
# 고기	0.09206480532884598
# 참나	0.09206480532884598
# 짜증	0.09206480532884598
# 대박	0.09206480532884598
# 하나	0.08619929850101471
# 지점	0.08619929850101471
# 아니다	0.00023340986808761954
#
# == Topic #12 ==
# Labels: 맵다 후라이드 가슴 적당하다 아이듥, 양념 맵다 후라이드 가슴, 아이 는데 후라이드 양념, 맵다 후라이드 가슴, 맵다 후라이드
# 보통	0.0974973514676094
# 아이	0.09143780171871185
# 후라이드	0.07621421664953232
# 음식	0.06947493553161621
# 맵다	0.06538887321949005
# 는데	0.04936949908733368
# 가슴	0.04936949908733368
# 적당하다	0.04936949908733368
# 아이듥	0.04936949908733368
# 양념	0.048975251615047455
#
# == Topic #13 ==
# Labels: 시간 다른 후기 배달, 이상하다 치킨, 빠르다 이상하다 치킨 많다, 다른 후기 배달, 배달 시간 다른
# 많다	0.09338712692260742
# 치킨	0.0783018171787262
# 추천	0.055843234062194824
# 별로	0.054417628794908524
# 가격	0.05114642530679703
# 좋다	0.04972081258893013
# 조금	0.04337206110358238
# 이상하다	0.042459387332201004
# 다른	0.038501154631376266
# 괜찮다	0.03850111737847328
#
#
# =====================결과======================
#
# 소비자들이 평가한 << 후라이드참잘하는집 >> 의 아쉬운점
#    Topic_num                           Topic_name  \
# 0        3.0              이상하다 후라이드 간장 + 안나 짠맛 일찍
# 1       13.0                시간 다른 후기 배달 + 이상하다 치킨
# 2       12.0  맵다 후라이드 가슴 적당하다 아이듥 + 양념 맵다 후라이드 가슴
#
#                                       Keywords   Score
# 0     간장, 소스, 안나, 살이, 살짝, 느낌, 짠맛, 일찍, 리뷰, 후라이드  2.0000
# 1    많다, 치킨, 추천, 별로, 가격, 좋다, 조금, 이상하다, 다른, 괜찮다  1.8333
# 2  보통, 아이, 후라이드, 음식, 맵다, 는데, 가슴, 적당하다, 아이듥, 양념  1.6667
