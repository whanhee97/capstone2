# %%
import pandas as pd
from pandas import DataFrame  as df
import numpy as np
from collections import Counter
from konlpy.tag import Okt
okt = Okt()
# %matplotlib inline
import matplotlib.pyplot as plt
import re 
from datetime import datetime
import tomotopy as tp


data = pd.read_excel('reviews_youngtong.xlsx')

# %% [markdown]
# # 메뉴 검색

# %%
user_input = "짜장"


arr = []

for i in range(len(data['메뉴'])):
    if type(data['메뉴'][i]) == str and user_input in data['메뉴'][i]:
        arr.append(data.loc[i])
        

searched_reviews = pd.DataFrame(arr, columns = ['지점명','유저','메뉴','리뷰','총점','맛','양','배달','시간'])

# %% [markdown]
# # 데이터 전처리

# %%
# 데이터 프레임의 '리뷰' 열의 값들을 str 형식으로 바꾸기
searched_reviews.리뷰 = searched_reviews.리뷰.astype(str)

# 중복데이터 삭제
searched_reviews.drop_duplicates(subset=['리뷰'],inplace=True)

# 한글이 아니면 빈 문자열로 바꾸기
searched_reviews['리뷰'] = searched_reviews['리뷰'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# 빈 문자열 NAN 으로 바꾸기
searched_reviews = searched_reviews.replace({'': np.nan})
searched_reviews = searched_reviews.replace(r'^\s*$', np.nan, regex=True)

# NAN 이 있는 행 삭제
searched_reviews.dropna(how='any', inplace=True)

# 인덱스 차곡차곡
searched_reviews = searched_reviews.reset_index (drop = True)

# 데이터 프레임에 null 값이 있는지 확인
print(searched_reviews.isnull().values.any())

# 리뷰 데이터를 리스트로 변환
Data_list = searched_reviews.리뷰.values.tolist()
# 정규화 처리
Data_list = list(map(okt.normalize,Data_list))
# Out:
# False

# %% [markdown]
# # 불용어 제거 및 토큰화

# %%
# 명사,형용사 추출
data_word = []

# 한글자 짜리는 모두 없애야 함
stopword = ['같다','이다','있다','여기','항상','완전','정말','너무','보고','오늘','역시','이번','다음','아주']

for i, document in enumerate(Data_list):
    clean_words = []
    for word in okt.pos(document, stem=True): #어간 추출
        if word[1] in ['Noun','Adjective']: 
            if len(word[0]) >= 2 and word[0] not in stopword:
                clean_words.append(word[0])    
    data_word.append(clean_words)
data_word
# Out:
# [['가깝다',
#   '중화요리',
#   '많다',
#   '굳이',
#   '주문',
#   '죄송하다',
#   '아이',
#   '맛있다',
#   '짜장면',
#   '짜장',
#   '고기',
#   '건더기',
#   '많다',
#   '고기',
#   '한참',
#   '탕수육',
#   '세트',
#   '탕슉',
#   '양념',
#   '종류',
#   '주심',
#   '맵다',
#   '칠리',
#   '취저',
#   '냄새',
#   '하나',
#   '튀김',
#   '산뜻',
#   '눅지',
#   '만두',
#   '냉장고',
#   '만두',
#   '이집',
#   '바로',
#   '만두',
#   '맛집',
#   '배달',
#   '쿠폰',
#   '메모',
#   '많다',
#   '장님',
#   '부디',
#   '번창',
#   '죄송하다',
#   '주문'],
#  ['맛있다'],
#  [],
#  ['간짜장', '간도', '면도', '좋다', '맛있다', '만두', '서비스', '좋다'],
#  ['양도', '많다', '맛있다'],
#  ['맛있다', '배달', '빨르다'],
#  ['탕수육', '섭취', '어려움', '정도', '딱딱하다', '심지어', '부분', '많다', '기분', '굉장하다', '좋다'],
#  ['간짜장', '맛있다', '탕수육', '맛있다', '짬뽕', '별로'],
#  ['맛있다'],
#  ['배달', '빠르다', '맛있다', '가게', '저렴하다', '맛있다'],
#  ['중국집', '맛있다'],
#  ['김치볶음밥',
#   '맛있다',
#   '후라이팬',
#   '살짝',
#   '아쉽다',
#   '짜장',
#   '인간',
#   '매우',
#   '별로',
#   '짜장',
#   '소스',
#   '밋밋하다',
#   '급식',
#   '짜장',
#   '소스',
#   '짜파게티',
#   '반도',
#   '너무하다',
#   '고추',
#   '짜장',
#   '쟁반짜장',
#   '맛있다',
#   '짜장',
#   '안되다'],
#  ['짠맛', '싱겁다', '적당하다', '부담', '맘껏', '사진'],
#  ['빠르다',
#   '배달',
#   '양도',
#   '많다',
#   '탕수육',
#   '바삭',
#   '맛있다',
#   '짬뽕',
#   '다른',
#   '음식',
#   '조금',
#   '싱겁다',
#   '스타일',
#   '신랑',
#   '괜찮다'],
#  ['명불허전', '자주', '다이어트', '때문', '탕수육', '주문', '인내', '시간', '충족', '담번', '주문', '번창'],
#  ['맛있다', '개인', '의견', '짬뽕', '양파', '추가', '주시', '맛날'],
#  ['맛있다', '콜라'],
#  ['빠르다', '배달', '한양'],
#  ['단골', '요즘', '자장면', '맛집'],
#  ['탕수육', '최고'],
#  ['짜장',
#   '탕수육',
#   '미리',
#   '다시',
#   '기고',
#   '튀김',
#   '딱딱하다',
#   '먹기',
#   '불편하다',
#   '차라리',
#   '마트',
#   '생각',
#   '먹는둥',
#   '마는',
#   '음식물',
#   '식사',
#   '하연',
#   '기분',
#   '안좋다'],
#  ['맛있다'],
#  ['맛있다', '짜장', '배기', '짜장', '부족하다', '짜장', '조금', '부탁드리다', '짬뽕', '지난번', '맛있다'],
#  ['좋다', '깔끔하다', '양도', '많다'],
#  ['맛있다'],
#  ['맛있다', '짬뽕', '재료', '많다', '싱싱하다', '국물', '맛있다'],
#  ['상하이',
#   '주문',
#   '짜장면',
#   '짬뽕',
#   '배달',
#   '해주시',
#   '맛있다',
#   '단무지',
#   '넉넉하다',
#   '주시',
#   '아이',
#   '맛있다'],
#  ['배달', '진짜', '빠르다'],
#  ['맛있다', '탕슉'],
#  ['쟁반짜장', '기름', '많다', '부담스럽다', '느끼하다', '탄산음료', '야하다', '짜장', '기름'],
#  ['간짜장', '인기', '메뉴', '살짝', '아쉽다', '만두', '짬뽕'],
#  ['맛있다', '사진', '없다'],
#  ['맛있다'],
#  ['짬뽕', '맛집', '급하다', '사진', '없다'],
#  ['맛있다'],
#  [],
#  ['안치',
#   '분만',
#   '당황',
#   '어플',
#   '분후',
#   '도착',
#   '클라스',
#   '이사',
#   '음식',
#   '담백하다',
#   '깔끔하다',
#   '좋다',
#   '바로',
#   '저장'],
#  ['양도', '맛있다'],
#  ['신기하다', '맛있다', '자주', '주문'],
#  ['맛있다', '서비스', '만두', '좋다'],
#  [],
#  ['중국집', '먹음', '맛있다'],
#  ['맛있다', '해물', '많다', '계속'],
#  ['맛있다'],
#  ['네사', '부모님', '주문', '부모님', '맛있다', '만족하다'],
#  ['배달', '빠르다'],
#  ['맛있다'],
#  ['양도', '많다', '최고'],
#  ['주문', '상하이'],
#  ['삼선짬뽕', '짱짱맨'],
#  ['맛있다', '배달', '아쉽다'],
#  ['배달',
#   '예상',
#   '시간',
#   '좋다',
#   '쟁반짜장',
#   '볶음밥',
#   '맛있다',
#   '무엇',
#   '국물',
#   '대박',
#   '배고프다',
#   '사진',
#   '바로'],
#  ['폭우', '배달', '맛있다', '양도', '많다'],
#  ['짬뽕', '맛있다', '서비스', '만두', '좋다', '최근', '정도', '모두', '짜장면', '멋있다'],
#  ['맛있다', '굳다', '굳다', '굳다'],
#  ['짬뽕', '국물', '서비스', '맛있다'],
#  ['배달', '빠르다', '양도', '많다', '맛있다'],
#  ['모두', '만족하다', '짬뽕', '국물', '넉넉하다', '맛있다'],
#  ['배달', '만족하다'],
#  ['짜장', '굳다', '짬뽕', '맛없다', '배고프다', '절반', '탕수육'],
#  ['많다', '맛있다', '빠르다', '배달'],
#  ['맛있다'],
#  ['간짜장', '짬뽕', '맛집'],
#  ['동네', '중식', '실망', '중식', '맛집', '리뷰', '많다', '주문', '성공하다'],
#  ['제일', '맛있다', '주문', '강추'],
#  ['신랑',
#   '점심식사',
#   '출근',
#   '마땅하다',
#   '없다',
#   '상하이',
#   '전화',
#   '이상',
#   '소요',
#   '배달',
#   '좋다',
#   '양도',
#   '깔끔하다',
#   '상하이',
#   '진심',
#   '추천',
#   '만두',
#   '서비스',
#   '맛있다',
#   '내사',
#   '상하이',
#   '지금',
#   '번창'],
#  ['짜장', '짬뽕', '배달', '빠르다', '맛있다'],
#  ['맛있다', '배달', '불친절'],
#  ['양도', '배달', '시간', '리뷰', '이벤트', '이구', '짬뽕', '얼큰하다', '좋다', '짬뽕', '처음', '맛있다'],
#  ['짜장면', '탕수육', '맛있다'],
#  ['좋다'],
#  ['양도', '많다', '맛있다', '배달', '빠르다', '탕슉', '바삭', '양념'],
#  ['상하이', '정착', '탕수육', '소스', '가지'],
#  ['배달'],
#  ['진짜', '많다'],
#  ['고추', '짜장', '생각', '기분', '나쁘다', '맵다', '아니다'],
#  ['진짜', '맛있다'],
#  ['배달', '빠르다', '맛있다', '배달', '분도', '친절하다', '기분', '좋다'],
#  ['맛있다'],
#  ['간짜장',
#   '탕수육',
#   '짬봉밥',
#   '볶음밥',
#   '리뷰',
#   '가장',
#   '많다',
#   '중국집',
#   '많다',
#   '기대',
#   '간짜장',
#   '짜장',
#   '소스',
#   '조금',
#   '퍽퍽',
#   '없다',
#   '탕수육',
#   '맛있다',
#   '눅눅',
#   '나은',
#   '짬뽕',
#   '볶음밥'],
#  [],
#  ['맛잇게먹엇어', '상하이'],
#  ['맛있다'],
#  ['맛있다', '배달', '배고프다', '좋다'],
#  ['짜장', '짬뽕', '탕수육', '중귝', '요리', '대장', '맛있다'],
#  ['많다', '배부르다', '주문', '조정', '부분', '좋다'],
#  [],
#  ['여전하다', '맛있다'],
#  ['음식', '맛있다', '배달', '오신', '기분', '나쁘다', '어후', '짜증나다', '사람', '인사', '거리', '면서'],
#  ['최고'],
#  ['배달', '빠르다', '맛있다', '용하다'],
#  ['조금', '뿔었', '맛있다'],
#  ['우리', '동네', '맛집', '똑같다'],
#  ['많다', '세트', '메뉴', '조합', '좋다', '탕수육', '바삭', '짜장', '좋다'],
#  ['맛있다'],
#  ['배달', '맛있다'],
#  ['주문',
#   '금방',
#   '탕수육',
#   '딱딱하다',
#   '맛있다',
#   '소스',
#   '맵다',
#   '맵다',
#   '좋다',
#   '짜장면',
#   '살짝',
#   '평범하다',
#   '맛있다'],
#  ['수고'],
#  ['맛있다', '깔끔하다'],
#  ['좋다', '배달', '기사', '친절하다'],
#  ['배달', '빠르다', '맛있다', '양도', '많다', '사이다', '서비스'],
#  ['평이하다', '배달', '빨르다', '배달', '친절하다', '리뷰', '이벤트', '만두', '이외', '하나'],
#  ['조금', '간이', '여름', '맛있다', '양도', '괜찮다', '평타', '이상은'],
#  ['배송', '생각', '리오', '셧구', '친절하다', '잡채', '배달', '조금', '불어', '그렇다', '서비스', '좋다'],
#  ['양도', '많다', '맛있다'],
#  ['쟁반짜장',
#   '포장',
#   '기전',
#   '볼품',
#   '없다',
#   '어른',
#   '쟁반짜장',
#   '아이',
#   '짜장',
#   '짬짜면',
#   '쟁반짜장',
#   '맛있다',
#   '탕수육',
#   '촉촉하다',
#   '맛있다'],
#  ['짜장',
#   '짬뽕',
#   '탕수육',
#   '맛있다',
#   '엄지',
#   '양장',
#   '미지근하다',
#   '기름',
#   '많다',
#   '양장',
#   '고유',
#   '매콤',
#   '어렵다'],
#  ['맛있다'],
#  ['통화',
#   '시간',
#   '어도',
#   '맛있다',
#   '단지',
#   '조금',
#   '아쉽다',
#   '비닐',
#   '얇다',
#   '인지',
#   '음식',
#   '뜨겁다',
#   '인지',
#   '탕수육',
#   '만두',
#   '포장',
#   '비닐',
#   '중간',
#   '중간',
#   '구멍',
#   '찝찝하다',
#   '그렇다',
#   '불구',
#   '주문',
#   '맛있다'],
#  ['맛있다'],
#  ['탕수육', '조금', '딱딱하다', '전반', '깔끔하다', '맛있다'],
#  [],
#  ['맛있다', '좋다', '서비스', '주신', '만두', '좋다'],
#  ['회사', '자주', '사진', '맛있다', '음식'],
#  [],
#  ['맛있다', '양도', '많다', '서비스', '감사'],
#  ['중화요리', '변하다', '음식', '친절하다', '유지', '좋다', '오래오래', '영업'],
#  ['예전'],
#  ['자장면', '볶음밥', '불어', '시간', '거의', '맞춤', '예전', '이아'],
#  ['짬봉', '국물', '없다'],
#  ['탕수육', '진짜', '맛있다', '소스', '맛있다'],
#  ['맛있다'],
#  ['탕수육', '고기', '오래되다', '아니다', '탕수육', '딱딱하다', '먹음'],
#  ['덥다', '빠르다', '배달', '맛있다'],
#  ['배달', '시간', '맛있다'],
#  ['맛있다', '진짜', '많다', '탕수육', '쫄깃쫄깃', '배부르다', '탕수육', '저녁'],
#  [],
#  ['짜장면',
#   '맛있다',
#   '좋다',
#   '배달',
#   '문자',
#   '그냥',
#   '조금',
#   '당황',
#   '스럽다',
#   '뭔가',
#   '이상하다',
#   '금방',
#   '음식',
#   '상태',
#   '괜찮다',
#   '맛있다'],
#  ['맛있다'],
#  ['스피드', '배달', '음식'],
#  ['없다', '짜장', '짬뽕', '노맛임'],
#  ['음식', '그렇다', '배달', '별로', '대행', '기사', '아니다', '대행', '직원', '교육', '문제'],
#  ['짜장면', '맛있다', '배달', '빠르다'],
#  ['많다'],
#  ['배송', '빠르다', '주문'],
#  ['탕수육', '바삭', '간짜장', '소스', '붇다'],
#  [],
#  ['짬뽕',
#   '맛있다',
#   '배달',
#   '짜장면',
#   '불어',
#   '덩어리',
#   '힘들다',
#   '요즘',
#   '시국',
#   '그렇다',
#   '짜장',
#   '소스',
#   '다르다',
#   '밍밍',
#   '춘장',
#   '정도',
#   '간도',
#   '심심하다',
#   '기선',
#   '짬뽕'],
#  ['뿔었어'],
#  ['맛있다'],
#  ['배달', '뺑뺑', '이돌', '짜장'],
#  ['식후감', '맛있다'],
#  ['진짜', '미치다', '조각', '짜장면', '생각'],
#  ['간짜장', '짜장', '다시', '맛있다'],
#  ['예상외',
#   '배달',
#   '조금',
#   '그거',
#   '별로',
#   '신경안',
#   '상관없다',
#   '양도',
#   '적당하다',
#   '맛있다',
#   '단무지',
#   '체크',
#   '놀래다',
#   '좋다'],
#  ['우선', '음식', '평가전', '거의', '분만', '배달', '짜장면', '불어', '별로', '탕수육'],
#  ['배송', '빠르다', '맛있다', '음식', '상하이', '주문', '맛있다', '주문'],
#  ['요청', '사항'],
#  ['맛있다',
#   '처음',
#   '간이',
#   '살짝',
#   '부족하다',
#   '간도',
#   '쎄다',
#   '맛있다',
#   '깔끔하다',
#   '포장',
#   '좋다',
#   '점심시간',
#   '배달',
#   '좋다'],
#  ['생각', '놀래다'],
#  ['새벽', '주문', '배달', '빠르다', '양도', '많다'],
#  ['싱겁다', '괜찮다', '짬뽕', '맛있다'],
#  ['불지', '배달'],
#  ['불변', '진리', '상하이', '맛있다', '식지', '탕수육', '맛있다', '만두', '맛있다'],
#  ['흡족하다', '만족스럽다'],
#  ['왠만하다',
#   '후기',
#   '안남',
#   '도데',
#   '수가',
#   '없다',
#   '짜장면',
#   '소스',
#   '오지',
#   '불어',
#   '개인',
#   '제외',
#   '탕수육',
#   '고기',
#   '나뭇가지',
#   '아니다',
#   '다말',
#   '고기',
#   '후기',
#   '너무하다'],
#  ['배탈', '친절하다'],
#  ['배달', '빠르다', '맛있다'],
#  ['맛있다', '음식', '없다', '배달', '주시', '삼촌', '친절하다', '음식'],
#  ['주문', '맛있다'],
#  ['맛있다'],
#  ['배달', '빠르다', '따뜻하다', '맛있다'],
#  ['짬뽕', '저번', '달리', '맑은', '느낌', '콩나물', '시원하다', '없다', '쪼끔', '아쉽다'],
#  ['짜장면', '서비스', '번창'],
#  ['배달', '생각', '빨르다', '불지', '뜨겁다', '상태', '그대로', '만두', '굿굿', '간짜장', '짬뽕', '맛있다'],
#  ['좋다', '좋다'],
#  ['탕수육', '짜장', '짬뽕', '맛있다'],
#  ['혼자', '먹기', '많다', '맛있다', '양도', '좋다'],
#  ['맛있다'],
#  ['음식', '정성', '느낌'],
#  ['중국집', '상하이'],
#  ['다르다', '괜찮다', '짜장면', '우동', '조금', '신경', '좋다'],
#  ['배달',
#   '시간',
#   '시간',
#   '배달',
#   '시간',
#   '주문',
#   '손가락',
#   '해지',
#   '당연하다',
#   '칭찬',
#   '탕수육',
#   '소스',
#   '맵다',
#   '다시',
#   '고려'],
#  ['양도', '최고'],
#  ['많다', '맛있다'],
#  ['짬뽕', '국물', '없다', '짬뽕', '매우'],
#  ['양도', '괜찮다', '탕수육', '맛있다'],
#  ['동네', '맛집', '맛있다'],
#  ['짜장면',
#   '짬뽕',
#   '맛있다',
#   '오오오',
#   '만두',
#   '맛있다',
#   '탕수육',
#   '살짝',
#   '눅눅하다',
#   '소스',
#   '가지',
#   '맛있다',
#   '짬뽕',
#   '리뷰',
#   '걱정',
#   '전혀',
#   '맛있다'],
#  ['진짜',
#   '계속',
#   '맛있다',
#   '양도',
#   '진짜',
#   '많다',
#   '혼자',
#   '그릇',
#   '약간',
#   '힘들다',
#   '배달',
#   '면도',
#   '맛있다',
#   '짬뽕',
#   '국물',
#   '얼큰하다',
#   '좋다',
#   '짜장면',
#   '맛있다',
#   '건더기',
#   '많다',
#   '고기',
#   '재미',
#   '진짜',
#   '좋다',
#   '맛있다',
#   '팽이',
#   '빙그르르',
#   '빙그르르',
#   '빙그르르',
#   '빙그르르',
#   '빙그르르',
#   '루느르',
#   '노르',
#   '르를르르류르'],
#  ['맛있다', '음식', '더맛', '된거'],
#  ['배달', '빠르다'],
#  ['맛있다'],
#  ['불어', '주문'],
#  ['불어',
#   '시간',
#   '지체',
#   '맛있다',
#   '자장면',
#   '아깝다',
#   '아이',
#   '정도',
#   '셋트주문할때',
#   '괜찮다',
#   '조금',
#   '실망'],
#  ['맛있다'],
#  ['시간', '배달', '감사', '서비스', '자주', '이용', '이유'],
#  ['맛있다'],
#  ['탕수육',
#   '진짜',
#   '바삭',
#   '맛있다',
#   '짬봉',
#   '칼칼하다',
#   '쟁반짜장',
#   '새우',
#   '오징어',
#   '해산물',
#   '진짜',
#   '많다',
#   '맛있다',
#   '굿굿'],
#  ['빠르다', '배달', '좋다', '간짜장', '춘하'],
#  ['처음', '괜찮다'],
#  ['배달', '스피드', '모두', '만족'],
#  ['제발', '홍합', '좋다'],
#  ['탕수육', '딱딱하다', '소스', '감안', '맛있다', '바닥', '음식', '그대로'],
#  ['삼선', '짜장', '삼선짬뽕', '좋다', '건더기', '짐해'],
#  ['제나', '맛있다', '배달', '빨르다'],
#  ['맛있다'],
#  ['맛있다'],
#  ['탕수육', '맛있다'],
#  ['맛있다', '배달', '빨르다'],
#  ['비빔냉면',
#   '인대',
#   '정체',
#   '없다',
#   '고기',
#   '비리다',
#   '비빔면',
#   '탕수육',
#   '딱딱하다',
#   '고기',
#   '분기',
#   '하나',
#   '없다',
#   '분기',
#   '튀김',
#   '눅눅하다',
#   '고기',
#   '딱딱하다',
#   '최악',
#   '느꼇내',
#   '탕수육',
#   '냉면',
#   '짜장'],
#  ['훌륭하다', '짜장', '준수'],
#  ['쟁반짜장', '탕수육', '맛있다', '짬뽕', '그냥', '그렇다'],
#  [],
#  ['맛있다'],
#  ['배달'],
#  ['배달', '좋다', '탕수육', '몇개'],
#  ['맛있다', '양도', '많다', '볶음밥', '소스', '조금', '부족하다'],
#  ['맛있다', '자주', '용하다'],
#  ['열시', '저녁', '배고프다', '사진', '원래', '중국집', '배달', '분만', '사진'],
#  ['맛있다'],
#  ['콩국수', '좋다'],
#  ['탕수육', '고기', '약간', '아쉽다'],
#  ['맛있다'],
#  ['맛있다'],
#  ['맛있다', '변하다', '짬뽕', '콩나물', '국물', '맛있다'],
#  ['맛있다'],
#  ['탕수육', '소스', '가지', '좋다'],
#  ['아이', '맛있다'],
#  ['빠르다', '배송', '맛있다'],
#  ['탕수육', '바삭'],
#  ['양도', '맛있다'],
#  ['배달', '간이', '맛있다'],
#  ['맛있다'],
#  ['집앞',
#   '상가',
#   '일이',
#   '변경',
#   '깜빡',
#   '배달',
#   '기사',
#   '전화',
#   '주시',
#   '원래',
#   '저희',
#   '아이',
#   '최애',
#   '짜장',
#   '곱빼기',
#   '정도',
#   '넉넉하다',
#   '단무지',
#   '맛있다'],
#  ['시간'],
#  ['리뷰', '오지', '배달', '빠르다', '짜장', '물이', '많다', '약간', '아쉽다', '제발'],
#  ['개인', '짬뽕', '탕수육', '맛있다', '이벤트', '서비스', '주신', '만두'],
#  ['맛있다', '사장', '리뷰', '이벤트', '요청', '사항', '확인', '단무지', '달라', '요청'],
#  ['맛있다', '그거', '최고', '아니다'],
#  ['배달', '빠르다', '맛있다'],
#  ['맛있다'],
#  ['실망', '음식', '맛있다', '번창'],
#  [],
#  ['맛있다'],
#  ['처음', '음식', '맛있다', '짬뽕', '독특하다', '제입', '국물', '쟁반짜장', '맛있다', '추천'],
#  ['요청', '사항', '맛있다'],
#  ['짜장', '군마'],
#  ['좋다', '배달', '빠르다'],
#  ['소주', '한잔', '짬뽕', '국물', '조금', '부탁', '탕수육', '안질', '기고', '맛있다'],
#  ['서비스'],
#  ['맛있다'],
#  ['양도', '많다', '만족스럽다'],
#  ['야식', '양도', '괜찮다'],
#  ['짜장면', '춘장', '예전', '진하다'],
#  ['맛있다', '짜장', '장도', '넉넉하다'],
#  ['양도', '많다', '쟁반짜장', '맛있다', '짬뽕', '얼큰하다', '맛있다'],
#  ['맛있다', '짬뽕', '탕수육', '최고', '주방', '장님', '솜씨', '좋다'],
#  ['간짜장', '살짝', '탕수육', '맛있다', '신경'],
#  ['진짜', '맛있다', '볶음밥', '처음', '실망'],
#  ['서비스', '만두', '맛있다'],
#  [],
#  ['배달', '간반', '괜찮다'],
#  ['짬뽕', '맛있다'],
#  ['배달', '빠르다', '음식'],
#  [],
#  ['양도', '구성', '좋다'],
#  ['맛있다', '간짜장', '맛있다'],
#  ['짜장면', '맛집', '추하다', '허겁지겁', '사진', '없다'],
#  ['빠르다', '배달', '친절하다', '사장', '주문'],
#  ['사진', '깜짝', '뭔가', '맛있다', '배달', '빠르다', '맛있다'],
#  ['맛있다', '간짜장'],
#  ['맛있다', '매번', '다른', '요청', '사항'],
#  ['맛있다'],
#  ['음식', '맛있다'],
#  ['양도', '좋다', '배달', '좋다'],
#  ['짜장면', '주문', '좋다', '양도', '불리', '좋다'],
#  ['면도', '맛있다', '양도', '많다'],
#  ['진짜', '맛임', '추천'],
#  ['많다', '소스', '부족하다', '맛있다', '탕수육', '맵다', '달콤', '소스'],
#  ['주문', '의사', '탕수육', '바삭', '고소하다'],
#  ['맛있다', '간짜장', '제육', '짬뽕', '맛있다'],
#  ['빠르다', '배달', '깔끔하다', '좋다'],
#  ['꿀맛', '꿀꿀', '휴가', '행복하다'],
#  ['처음', '주문', '맛있다', '주문'],
#  ['맛있다'],
#  ['사진',
#   '없다',
#   '진짜',
#   '배달',
#   '친절하다',
#   '흠잡다',
#   '없다',
#   '알바',
#   '아니다',
#   '맛있다',
#   '렬루다',
#   '트루',
#   '스토리'],
#  ['맛있다', '사장'],
#  [],
#  ['잘먹엇습니'],
#  ['짬뽕', '두번째', '맛있다'],
#  ['맛있다'],
#  ['맛있다', '리뷰', '만두', '서비스'],
#  ['자장면', '덩어리', '겨우', '탕수육', '아래', '따뜻하다', '부드럽다', '아래'],
#  ['짬뽕', '국물', '달라', '요청', '사항'],
#  ['맛있다'],
#  ['우선',
#   '배달',
#   '신분',
#   '친절하다',
#   '기분',
#   '좋다',
#   '짬뽕',
#   '해산물',
#   '놀래다',
#   '맛있다',
#   '짬뽕',
#   '입맛',
#   '조금',
#   '싱겁다',
#   '해산물',
#   '배부르다',
#   '탕수육',
#   '소스',
#   '가지',
#   '더욱',
#   '좋다'],
#  ['조금', '불어', '맛있다'],
#  ['맛있다'],
#  ['진짜', '맛있다'],
#  ['빠르다', '친절하다', '배달'],
#  ['요즘', '배달', '업체', '바로', '아니다', '군데', '짜장면'],
#  ['주문', '빠르다', '보장', '만족하다', '다만', '잡채', '조금', '싱겁다', '아쉽다', '담번', '부탁드리다'],
#  ['리뷰', '탕수육', '빠삭'],
#  ['쟁반짜장', '맛있다', '제육', '아니다', '저기', '주황색', '비리', '느끼하다', '제육', '주방', '차이'],
#  ['맛있다', '배달', '감사'],
#  ['맛있다', '탕수육', '평소', '다르다'],
#  ['맛있다', '안전하다', '포장', '제일'],
#  ['짜장면',
#   '괜찮다',
#   '잘못',
#   '배달',
#   '오시',
#   '음식',
#   '트레이',
#   '맨손',
#   '짜장면',
#   '그릇',
#   '간짜장',
#   '소스',
#   '그릇',
#   '단무지',
#   '네가지',
#   '아슬아슬하다',
#   '비도',
#   '음식',
#   '횡하',
#   '노출',
#   '상태',
#   '배달',
#   '직하다'],
#  ['탕수육', '맛있다', '양도', '넉넉하다', '맛있다'],
#  [],
#  ['모두', '훌륭하다'],
#  ['맛있다'],
#  ['말증',
#   '없다',
#   '최초',
#   '작성',
#   '삼선',
#   '고추',
#   '짜장',
#   '아리',
#   '탱탱',
#   '불어',
#   '삼선짬뽕',
#   '간도',
#   '충격',
#   '이후',
#   '두번째',
#   '종종',
#   '맛있다'],
#  ['맛있다', '많다'],
#  ['맛있다', '바로', '사진', '읎어', '간짜장', '조금', '싱겁다'],
#  ['탕수육', '겉바', '맛있다', '무엇', '많다', '좋다'],
#  ['맛있다', '쟁반짜장', '해물', '짬뽕', '국물', '만두', '맛있다'],
#  ['리뷰', '죄송하다', '맛있다'],
#  [],
#  ['배달'],
#  ['좋아하다', '짜장'],
#  ['쟁반짜장',
#   '없다',
#   '주문',
#   '쟁반짜장',
#   '약간',
#   '불어',
#   '맛있다',
#   '짬뽕',
#   '국물',
#   '많다',
#   '아래',
#   '오징어',
#   '죽순',
#   '야채',
#   '많다',
#   '고봉',
#   '많다',
#   '서비스',
#   '주신',
#   '만두'],
#  ['양도', '많다', '맛있다'],
#  ['맛있다'],
#  ['곱빼기', '제대로', '콜라', '서비스'],
#  ['배달', '빠르다', '맛있다', '세트', '메뉴', '구성', '좋다'],
#  ['근처',
#   '중국집',
#   '많다',
#   '주문',
#   '배달',
#   '일단',
#   '친절하다',
#   '리뷰',
#   '이벤트',
#   '주신',
#   '만두',
#   '진짜',
#   '맛있다',
#   '탕수육',
#   '소스',
#   '종류',
#   '짜장면',
#   '짬뽕',
#   '기본',
#   '메뉴',
#   '맛있다',
#   '계속',
#   '애용',
#   '생각'],
#  ['평소', '맛있다', '평점', '배달', '업체', '짬뽕', '국물', '진짜', '신경'],
#  ['용하다', '맛있다'],
#  ['바삭', '식감', '좋다', '달콤하다', '소스', '등심', '좋다', '맛있다', '탕수육', '적극', '강추'],
#  ['매번', '양도', '많다', '좋다'],
#  ['탕수육', '맛있다'],
#  ['맛있다', '빨르다'],
#  ['양도', '많다', '서비스', '만두'],
#  ['맛있다'],
#  [],
#  [],
#  ['상하이',
#   '간짜장',
#   '잡채',
#   '간짜장',
#   '맛있다',
#   '잡채',
#   '또한',
#   '맛있다',
#   '소스',
#   '부족하다',
#   '깨끗하다',
#   '중국집'],
#  ['짜장', '오므라이스', '배달', '빠르다'],
#  ['깔끔하다', '맛있다'],
#  ['짜장', '간짜장', '청양고추', '맛있다'],
#  ['음식', '맛있다', '짬뽕', '국물', '달리', '요청', '짬퐁', '그릇', '맛있다'],
#  ['자주', '맛있다'],
#  ['사람',
#   '귀찮다',
#   '새벽',
#   '시간',
#   '죄송하다',
#   '대충',
#   '아니다',
#   '일단',
#   '짜장',
#   '양파',
#   '많다',
#   '그렇다',
#   '약간',
#   '짜장',
#   '느낌',
#   '짜장면',
#   '특유',
#   '윤기',
#   '없다',
#   '이상하다',
#   '배달',
#   '빨르다',
#   '고생',
#   '가장',
#   '중요하다',
#   '이상하다',
#   '음식',
#   '무슨',
#   '비닐',
#   '시간',
#   '오전',
#   '일찍',
#   '주문',
#   '괜찮다',
#   '생각',
#   '그때',
#   '시간',
#   '서비스',
#   '마인드',
#   '건가'],
#  ['빠르다', '배달', '짜장면', '감사'],
#  ['양도', '많다', '깔끔하다', '담백하다', '평촌', '가장', '중국집', '아니다'],
#  ['산선', '짬뽕', '국물', '없다', '비빔면', '느낌'],
#  ['많다', '맛있다'],
#  ['양도', '진짜', '많다', '맛있다'],
#  [],
#  ['맛있다'],
#  ['고민', '중국음식', '상하이', '주문', '맛있다', '최고', '중국', '배달', '전문점', '인정'],
#  ['맛있다'],
#  ['맛있다', '서비스', '만두'],
#  [],
#  ['주문', '정도', '상하이', '중독'],
#  ['맛있다', '최고'],
#  ['양도',
#   '많다',
#   '국물',
#   '진국',
#   '라며',
#   '아이',
#   '좋아하다',
#   '짬뽕',
#   '강추',
#   '짜장',
#   '맛있다',
#   '대요',
#   '불맛',
#   '제대로'],
#  ['맛있다', '많다', '배부르다'],
#  ['양도', '맛있다'],
#  ['무난', '맛있다', '자주'],
#  ['새우', '튀김'],
#  [],
#  ['자주', '숙국'],
#  ['배달', '빠르다', '좋다', '자주'],
#  ['짬뽕',
#   '맛있다',
#   '서비스',
#   '만두',
#   '당면',
#   '만두',
#   '아니다',
#   '고기',
#   '그냥',
#   '맛있다',
#   '탕수육',
#   '고기',
#   '정확하다',
#   '아깝다',
#   '탕수육',
#   '소스',
#   '가지',
#   '취향',
#   '짜장면',
#   '맛있다'],
#  ['양도', '많다', '맛있다'],
#  ['배달', '빠르다', '맛있다'],
#  ['배달', '느리다', '면도'],
#  ['매번', '맛있다'],
#  ['빠르다', '배달', '좋다'],
#  ['사진',
#   '종종',
#   '사무실',
#   '주문',
#   '삼선짜장',
#   '주문',
#   '삼선',
#   '간짜장',
#   '짜장',
#   '간짜장',
#   '좋아하다',
#   '맛있다',
#   '해산물',
#   '신선하다',
#   '좋다'],
#  ['배송', '빠르다', '짜장', '연도', '맛있다'],
#  ['맛있다'],
#  [],
#  ['배달',
#   '모두',
#   '좋다',
#   '짜장면',
#   '탕수육',
#   '사용',
#   '고기',
#   '질도',
#   '좋다',
#   '다만',
#   '짜장면',
#   '불어',
#   '아쉽다'],
#  ['짬뽕', '짜장', '탕슉입니', '맛있다'],
#  ['짬뽕', '국물', '서비스', '주시', '짜장면', '약간', '매콤', '부분', '때문', '느끼하다', '탕수육', '바삭'],
#  ['양도', '많다', '굳다'],
#  ['넘치다',
#   '많다',
#   '쟁반짜장',
#   '맛있다',
#   '탕수육',
#   '방금',
#   '뜨겁다',
#   '바삭',
#   '짬뽕',
#   '국물',
#   '서비스',
#   '요청'],
#  ['간짜장',
#   '그동안',
#   '짜장',
#   '맛있다',
#   '삼선짬뽕',
#   '해물',
#   '어마어마하다',
#   '착하다',
#   '재료',
#   '깨끗하다',
#   '위생',
#   '맛있다'],
#  ['배달'],
#  ['한번', '짜장', '짬뽕', '만두', '모두', '맛있다'],
#  ['맛있다', '배달', '느리다', '살짝', '아쉽다'],
#  ['맛있다'],
#  ['짬뽕', '해물', '좋다'],
#  ['중국', '음식'],
#  ['맛있다', '탕슉', '짜장면', '쫄깃쫄깃', '짬뽕', '입맛'],
#  ['짜장', '잡채', '맛있다', '자주', '잡채', '하얗다', '조금', '싱겁다', '맛있다'],
#  ['잡탕', '쟁반', '맛있다', '자장면', '짬뽕', '별로', '짬뽕', '유부', '짜장', '어묵'],
#  ['맛있다', '짜장', '짬뽕', '맛있다', '중국음식'],
#  [],
#  ['좋다'],
#  ['짐해', '짜장', '짬뽕', '고민', '짬뽕'],
#  ['맛있다', '토마토소스'],
#  ['빠르다', '배달', '맛있다'],
#  ['중식', '맛있다'],
#  ['맛있다', '배달', '빠르다', '양도', '많다'],
#  ['배달', '예상', '시간', '포장', '제대로', '짜장'],
#  ['맛있다'],
#  ['리뷰', '맛있다'],
#  ['배달', '좋다', '좋다', '양도', '많다', '가성', '좋다'],
#  ['양도', '좋다'],
#  ['배달', '만두', '좋다', '좋다'],
#  ['맛있다'],
#  ['맛있다', '이서', '양자'],
#  ['회사', '맛있다'],
#  ['굿굿', '배달', '느렷어영'],
#  ['탕수육', '딱딱하다'],
#  ['맛있다', '새벽', '짜장', '짬뽕'],
#  ['친구', '집들이', '중국집', '음식', '상하이'],
#  ['어제', '리뷰', '맛있다'],
#  ['양도', '많다', '와이프', '애기', '맛있다'],
#  ['간짜장', '소스', '전화'],
#  ['얼른', '대충', '사진', '그렇다', '진짜', '일품', '나중'],
#  ['예전', '맛있다'],
#  ['짬뽕', '국물', '좋다'],
#  ['양도', '많다', '맛있다'],
#  ['방장', '실망'],
#  ['사랑',
#   '상하이',
#   '남편',
#   '재택',
#   '점심때',
#   '제육',
#   '볶음',
#   '삼선',
#   '쟁반짜장',
#   '주문',
#   '볶음',
#   '밥반',
#   '삼선도',
#   '재료',
#   '신선하다',
#   '면발',
#   '쫄깃쫄깃',
#   '맛있다',
#   '서비스',
#   '주신',
#   '만두',
#   '맛있다',
#   '상하이',
#   '없다',
#   '중식',
#   '배달',
#   '상상',
#   '없다',
#   '만족스럽다',
#   '점심',
#   '감사'],
#  ['자주', '만족스럽다', '소스', '가지', '맛있다'],
#  ['따뜻하다',
#   '상태',
#   '불지',
#   '쫄깃',
#   '면발',
#   '짬뽕',
#   '국물',
#   '얼큰하다',
#   '짜장면',
#   '소스',
#   '달달',
#   '감칠맛',
#   '중독',
#   '탕수육',
#   '바삭바삭하다',
#   '식감',
#   '최고'],
#  ['맛있다'],
#  ['만족하다', '추천'],
#  ['맛있다', '중국집', '제일', '맛있다'],
#  ['맛있다', '배달', '빨르다', '단골'],
#  ['배달',
#   '빨르다',
#   '주문',
#   '그렇다',
#   '탕수육',
#   '말르다',
#   '짜장면',
#   '밀가루',
#   '심하다',
#   '만두',
#   '제일',
#   '맛있다'],
#  ['좋다', '맛잉'],
#  ['볶음', '짬뽕', '간이', '안되다'],
#  ['매번', '맛있다', '양도', '넉넉하다', '주시', '좋다', '서비스', '만두', '맛있다'],
#  ['정신', '사진', '깜빡', '상하이', '기본', '충실하다', '짜장', '짬뽕', '만두'],
#  ['급하다',
#   '바람',
#   '사진',
#   '이제',
#   '상하이',
#   '짜장',
#   '맛있다',
#   '짬뽕',
#   '진하다',
#   '얼큰하다',
#   '맛있다',
#   '탕수육',
#   '만두',
#   '없다'],
#  ['탕수육', '맛집', '냄새', '안좋다', '거의'],
#  ['맛있다', '번창'],
#  ['맛있다', '급니', '양파', '달라', '요청'],
#  ['맛있다', '최소', '요금', '조금', '낮처'],
#  ['사진', '가요'],
#  ['배고프다',
#   '사진',
#   '깜빡',
#   '주문',
#   '음식점',
#   '양도',
#   '많다',
#   '깔끔하다',
#   '맛있다',
#   '탕수육',
#   '소스',
#   '가지',
#   '주시',
#   '번창'],
#  ['부터', '맛있다', '양도', '많다', '상하이'],
#  ['두번째', '처음', '국물', '탕수육', '딱딱하다', '짜장면', '느끼하다', '뚝뚝', '아쉽다'],
#  ['맛있다'],
#  ['쿠폰', '양장', '맛있다'],
#  ['서비스', '만두'],
#  ['생각',
#   '배달',
#   '빠르다',
#   '좋다',
#   '짬뽕',
#   '국물',
#   '불맛',
#   '만족스럽다',
#   '탕수육',
#   '딱딱하다',
#   '부드럽다',
#   '편이',
#   '짜장면',
#   '짬뽕',
#   '많다',
#   '편이',
#   '좋다'],
#  [],
#  ['배달', '분만', '총알', '맛있다'],
#  ['양도', '많다', '맛있다'],
#  ['맛있다', '요청', '사항'],
#  ['배달', '빠르다', '맛있다'],
#  ['음식'],
#  ['짜장', '탕수육', '소스', '맛있다', '서비스', '만두', '맛있다'],
#  ['배달', '빠르다', '쫄깃하', '맛있다', '많다'],
#  ['맛있다'],
#  ['이제', '리뷰', '안해'],
#  ['진짜', '하나', '저번'],
#  [],
#  ['처음', '맛있다', '짜장면', '서비스', '주신', '만두'],
#  ['사진', '급하다', '맛있다', '만두', '서비스'],
#  ['배달', '빠르다', '맛있다'],
#  ['완죤굿'],
#  ['배달', '짬뽕', '국물', '진짜', '깔끔하다', '맛있다'],
#  ['주문', '배달', '빠르다', '모두', '만족하다'],
#  ['맛있다', '써비스', '사이다', '단무지', '양파'],
#  ['배달', '빠르다', '좋다'],
#  ['맛있다', '소리', '양도', '많다', '배달', '굿굿', '리뷰', '이벤트', '콜라', '맛있다'],
#  [],
#  ['주문', '사진', '없다', '맛있다', '주문'],
#  ['급하다', '사진', '배달', '빠르다', '친절하다', '제일', '중요하다', '개꿀맛'],
#  ['쟁반짜장', '매콤', '간짜장', '맛있다', '만두', '알차다', '맛있다', '주문', '후회', '중국음식', '주문'],
#  ['굿굿', '맛있다'],
#  ['많다', '좋다'],
#  ['배달', '진짜', '빨르다', '분만', '양도', '많다', '맛있다', '배부르다'],
#  ['매콤', '느끼하다', '맛있다', '배달', '빠르다'],
#  ['상하이',
#   '맛있다',
#   '일반',
#   '짜장',
#   '간짜장',
#   '모두',
#   '맛있다',
#   '짬뽕',
#   '국물',
#   '진하다',
#   '좋다',
#   '양도',
#   '당연하다',
#   '많다',
#   '탕수육',
#   '바삭바삭하다',
#   '맛있다',
#   '주문',
#   '자마자',
#   '마음',
#   '급하다',
#   '사진',
#   '맛있다',
#   '음식'],
#  ['진짜', '맛있다', '만두', '후추', '강하다', '진짜', '안나', '후추'],
#  [],
#  ['인생', '중화요리'],
#  ['짜장', '맛있다', '짬뽕', '보통'],
#  ['거기', '빠르다', '배달', '좋다', '아이', '자마자', '사진', '없다', '상하이'],
#  ['양도', '많다', '음식', '식지', '맛있다'],
#  ['배달', '빠르다'],
#  [],
#  ['술국', '주문', '역대', '재료', '듬뿍', '신랑', '맛있다'],
#  ['많다', '맛있다', '탕수육', '소스', '가지', '좋다'],
#  ['맛있다', '짬봉', '국물', '조금', '달라', '요청', '짬뽕', '맛있다'],
#  ['일전', '맛있다'],
#  ['맛있다'],
#  ['잡채', '간짜장'],
#  ['맛있다', '양도', '많다'],
#  ['맛있다', '탕수육', '평소', '맛있다'],
#  ['단골',
#   '점점',
#   '실망',
#   '주문',
#   '한지',
#   '시간',
#   '배달',
#   '주말',
#   '그렇다',
#   '탕수육',
#   '어제',
#   '다시',
#   '고기',
#   '딱딱하다',
#   '튀김',
#   '기름',
#   '좔좔',
#   '짜장면',
#   '참전',
#   '따스하다',
#   '불어',
#   '없다',
#   '음식점',
#   '실망',
#   '스럽다',
#   '단골',
#   '슬프다'],
#  ['급하다', '맛있다', '사진', '맛있다', '짜장면', '맛있다'],
#  ['구성', '양도', '괜찮다'],
#  ['맛있다', '짬뽕', '국물', '서비스', '중국집', '최고', '주문'],
#  ['맛있다', '양도', '많다'],
#  ['짬뽕',
#   '국물',
#   '해장',
#   '때문',
#   '부탁드리다',
#   '감동',
#   '탕수육',
#   '쫄깃',
#   '맛있다',
#   '짜장면',
#   '나름',
#   '맛있다'],
#  ['주문'],
#  ['리뷰', '주문', '맛있다', '양도', '많다', '탕수육', '부드럽다', '짬뽕', '얼큰하다', '맛있다', '주문'],
#  ['다리', '아프다', '맛있다', '생각', '보더', '맛있다', '깜짝'],
#  ['많다', '좋다', '탕수육', '바삭', '눅눅하다', '상태', '안좋다', '다기', '스타일'],
#  ['맛있다'],
#  ['사람', '한번', '사람', '없다'],
#  ['맛있다', '만족스럽다', '자주', '배달', '빠르다', '좋다'],
#  ['배부르다'],
#  ['배달', '빠르다'],
#  ['사진', '못찍엇네', '자장면', '탕수육'],
#  ['맛있다', '배달'],
#  ['짜장',
#   '세트',
#   '짜장',
#   '고추',
#   '짜장',
#   '변경',
#   '고추',
#   '짜장',
#   '맛있다',
#   '양도',
#   '많다',
#   '배달',
#   '일찍',
#   '배달',
#   '분도',
#   '친절하다',
#   '빨갛다',
#   '소스',
#   '맛있다',
#   '요청',
#   '사항'],
#  ['좋다', '양도', '둘이서', '약간', '정도', '약간', '불어', '좋다'],
#  ['만두', '서비스', '맛있다', '요즘', '맛있다'],
#  ['맛있다', '고소하다', '맛있다'],
#  ['간짜장', '간이', '맛있다'],
#  ['인덕원역', '주변', '동네', '제일', '좋다', '최소한', '실패', '없다'],
#  ['배달', '맛있다'],
#  ['맛있다'],
#  ['맛있다',
#   '단골',
#   '예전',
#   '없다',
#   '연속',
#   '굴짬뽕',
#   '없다',
#   '짬뽕',
#   '헷갈리다',
#   '신건',
#   '공급',
#   '안되다',
#   '말씀'],
#  ['맛있다'],
#  ['이사', '일주일', '벌써', '사장', '친절하다', '음식', '맛있다'],
#  [],
#  ['근처',
#   '자주',
#   '배달',
#   '자장면',
#   '탕수육',
#   '평소',
#   '딱딱하다',
#   '혹시',
#   '방장',
#   '새롭다',
#   '불소',
#   '일지',
#   '입맛',
#   '그렇다',
#   '아니다',
#   '동생',
#   '주문',
#   '평소',
#   '맛있다',
#   '이상하다',
#   '이전',
#   '부탁드리다'],
#  ['짬뽕', '얼큰하다', '맛있다', '간짜장', '지금', '짜장', '최고'],
#  ['탕슉', '식구', '맛있다', '사진', '첨부', '짬뽕', '매번', '개운하다', '짜장', '업체', '좋다'],
#  ['맛있다', '서비스'],
#  ['규리'],
#  ['새벽', '좋다', '배달', '빠르다', '가끔', '짜장', '좋다', '디다'],
#  ['맛있다', '양도', '적당하다', '아영'],
#  ['근처', '중국', '음식점', '제일', '맛있다'],
#  ['맛있다', '서비스'],
#  ['맛있다', '불어'],
#  ['양도',
#   '좋다',
#   '다만',
#   '배달',
#   '배고프다',
#   '힘들다',
#   '시간',
#   '십분',
#   '이상',
#   '서비스',
#   '주신',
#   '만두',
#   '번창'],
#  ['맛있다', '배달', '빨르다'],
#  ['배달',
#   '분만',
#   '반갑다',
#   '짬뽕',
#   '얼큰하다',
#   '곱빼기',
#   '변경',
#   '신의',
#   '짬뽕',
#   '맛있다',
#   '상하이',
#   '탕수육',
#   '소스',
#   '좋다'],
#  ['짬뽕', '맛있다', '배달'],
#  ['자주', '만족', '중식', '없다', '주문'],
#  ['포장', '깔끔하다', '맛있다'],
#  ['예상', '시간', '좋다'],
#  ['배달', '맛있다', '쟁반짜장', '소스', '넉넉하다', '좋다', '만두', '맛있다', '아빠', '단무지', '맛있다'],
#  ['주문', '짜장면', '그렇다', '짜장면', '탕수육', '맛있다', '글구', '은근', '많다'],
#  ['맛있다'],
#  ['배달', '빠르다', '좋다', '양도', '넉넉하다'],
#  ['맛있다', '불리'],
#  ['맛있다', '불어', '탕수육', '만두', '맛있다'],
#  [],
#  ['배달', '자극', '좋다'],
#  ['처음', '짜장', '부족하다', '짬뽕', '야채', '밉다'],
#  ['배달', '좋다', '탕수육', '맛있다'],
#  ['양도', '많다', '좋다', '탕수육', '눅눅하다', '맛있다', '탕수육', '소스', '종류', '좋다'],
#  ['코로나',
#   '배달',
#   '문자',
#   '새롭다',
#   '맛집',
#   '짜장',
#   '맛집',
#   '이제야',
#   '발견',
#   '동네',
#   '아가',
#   '엄마',
#   '전파',
#   '짜장',
#   '원래',
#   '탕수육',
#   '급하다',
#   '사진'],
#  ['맛있다', '사장', '화이팅'],
#  ['배달', '빠르다', '맛있다'],
#  ['배달', '빠르다', '서비스'],
#  ['처음', '맛있다'],
#  ['탕수육', '바삭', '맛있다'],
#  ['생각', '배달', '좋다', '아이', '고프다', '맛있다', '음식', '순식간', '자주'],
#  ['맛있다', '사진'],
#  ['양도', '만두', '다른', '가게', '만두', '탕수육', '부드럽다', '좋다'],
#  ['양도', '많다', '맛있다', '만두', '주시', '탕슉', '생각', '많다', '짜장면', '맛있다'],
#  ['급하다', '사진', '없다', '배달', '도착', '연락', '맛있다'],
#  ['이아주', '좋다'],
#  [],
#  ['간도', '크게', '쎄다', '맛있다'],
#  ['음식', '괜찮다', '양도', '적절하다', '배달', '빨르다', '배달', '기사', '친절하다', '맛있다'],
#  ['맛있다'],
#  ['양도', '맛있다'],
#  ['맛있다', '리뷰', '이벤트'],
#  ['맛있다', '아들', '얼집', '졸업식', '짜장면', '중화요리', '상하이'],
#  ['맛있다', '배달', '빠르다', '쟁반짜장', '강추'],
#  ['주문'],
#  ['빠르다', '저렴하다', '좋다'],
#  ['배달', '빠르다', '맛있다'],
#  ['많다', '불리'],
#  ['진심', '맛있다', '중국음식', '필요없다'],
#  ['맛있다',
#   '양도',
#   '많다',
#   '좋다',
#   '무엇',
#   '국물',
#   '얘기',
#   '요청',
#   '사장',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '최고',
#   '이상',
#   '리뷰'],
#  ['일단', '짜장면', '맛있다', '탕수육', '나쁘다'],
#  [],
#  ['맛있다', '좋다'],
#  ['배달', '느리다', '좋다'],
#  ['조금', '빠르다', '배달', '주시', '좋다'],
#  ['맛있다', '사진'],
#  ['마잇', '서비스', '좋다', '비닐', '어디'],
#  ['배달', '놀람'],
#  ['배달', '빨르다'],
#  ['맛있다', '주문'],
#  ['맛있다', '양도', '진짜', '많다', '심지어', '고기', '버섯', '고급', '재료', '넉넉하다'],
#  ['좋다', '대기', '시간', '분만', '뱃가죽', '배고프다', '힘들다', '맛있다'],
#  ['쟁반짜장'],
#  ['맛있다', '음식'],
#  [],
#  ['배달', '빠르다', '상하이'],
#  ['배달', '빠르다', '좋다', '서비스'],
#  ['쿠폰', '얼른'],
#  ['맛있다'],
#  ['새벽', '맛있다', '배고프다', '바로', '사진'],
#  ['맛있다'],
#  ['기름', '깨끗하다', '탕수육', '튀김', '깨끗하다', '양도', '많다', '좋다'],
#  ['탕수육', '맛있다', '이제껏', '탕수육', '최고'],
#  ['굴짬뽕', '없다'],
#  ['맛있다',
#   '상하이',
#   '세트',
#   '알차다',
#   '구성',
#   '서비스',
#   '짬뽕',
#   '국물',
#   '감동',
#   '서비스',
#   '짬뽕',
#   '국물',
#   '내용물',
#   '많다',
#   '간짜장',
#   '탕수육',
#   '만두',
#   '맛있다',
#   '탕수육',
#   '소스',
#   '진짜',
#   '맛있다'],
#  ['굿굿'],
#  ['짜장면', '별로'],
#  ['단골', '맛있다'],
#  ['탕수육', '진짜', '맛있다', '짜장면', '맛있다', '배달', '빨르다', '거래처'],
#  ['맛있다'],
#  ['맛있다', '배달', '보통'],
#  ['짜장', '짬뽕', '탕수육', '맛있다'],
#  ['배달', '오신', '친절하다', '짜장면', '맛있다', '배달', '기사', '덕분', '기분', '좋다'],
#  ['맛있다', '쵝오'],
#  ['삼선', '고추', '짜장', '주문', '고추가', '개도', '없다', '삼선짜장', '잘못', '맛있다'],
#  ['탕수육', '바삭', '좋다'],
#  ['짜장면', '조금', '불어', '좋다'],
#  ['신나다', '발견', '머리카락', '절때', '주작', '아니다', '모습', '튀김'],
#  ['맛있다', '짬뽕', '국물', '맛있다'],
#  ['안양', '중식', '상하이', '맛있다'],
#  ['탕수육', '소스', '짜증나다', '나머진', '괜찮다'],
#  ['간짜장', '좋다'],
#  ['양도', '많다', '맛있다'],
#  ['매번', '배달', '체크', '꼼꼼하다'],
#  ['예상', '시간', '자주', '유독', '맛있다', '짜장면', '탕수육', '진짜'],
#  ['짬뽕', '해물', '많다'],
#  ['쟁반짜장', '맛있다'],
#  ['솔직하다',
#   '리뷰',
#   '세트',
#   '자장면',
#   '저렴하다',
#   '그렇다',
#   '탕수육',
#   '눅눅하다',
#   '기름',
#   '뚝뚝',
#   '짬뽕',
#   '일반',
#   '짬뽕',
#   '생각',
#   '먹기',
#   '다르다',
#   '시원하다',
#   '짭짤하다',
#   '사진',
#   '사진',
#   '생각'],
#  ['쟁반짜장', '진짜', '맛있다', '새우', '오징어', '혜자', '탕수육', '소스', '신기하다', '딱딱하다', '아쉽다'],
#  ['맛있다', '양도', '많다', '배달', '빨르다'],
#  ['맛있다', '짬뽕', '최고', '매콤', '콩나물', '시원하다'],
#  ['맛있다'],
#  ['굴짬뽕', '해산물', '많다', '실하다', '맑은', '국물', '최고'],
#  ['짜장면', '신맛'],
#  ['쟁반짜장', '맛있다'],
#  ['배달', '분도', '친절하다', '좋다'],
#  ['기사', '친절하다'],
#  ['탕수육', '눅눅하다', '에어', '프라이어', '면도', '짬뽕', '맛있다'],
#  ['맛있다', '배부르다', '바로', '리뷰'],
#  ['쟁반짜장', '최고', '동네', '중국집', '배달', '맛있다'],
#  ['최고', '맛있다', '삼선짬뽕', '상하이'],
#  ['맛있다'],
#  ['사실',
#   '깔끔하다',
#   '맛있다',
#   '음식',
#   '깨끗하다',
#   '배달',
#   '시간',
#   '사전',
#   '공지',
#   '배달',
#   '건강하다',
#   '주문'],
#  ['좋다', '배달'],
#  ['맛있다'],
#  ['빠르다', '친절하다', '배달', '짬뽕', '맛있다'],
#  ['맛있다'],
#  ['배달', '맛있다'],
#  ['간짜장', '불어', '소스', '차갑다', '고추', '단골', '실망', '스럽다', '상태', '배달', '이해'],
#  ['고추',
#   '부탁',
#   '짜장면',
#   '느글',
#   '거려',
#   '고추',
#   '짜장',
#   '맛있다',
#   '탕수육',
#   '소자',
#   '둘이서',
#   '배달',
#   '대행',
#   '아니다',
#   '메뉴',
#   '하나',
#   '하나',
#   '말씀',
#   '친절하다',
#   '탕수육',
#   '만두',
#   '빠삭하',
#   '맛있다'],
#  ['맛있다', '고추', '짬뽕', '얼근하다', '좋아하다', '양도', '넉넉하다'],
#  ['맛있다'],
#  ['예전', '몇번', '여전하다', '맛있다', '만두', '서비스'],
#  ['맛있다'],
#  ['주문', '상하이', '하나', '맛있다'],
#  ['배달', '순식간', '음식', '맛있다'],
#  ['최근', '짜장', '제일', '추하다', '관심', '등록'],
#  ['리뷰', '서비스'],
#  ['맛있다', '서비스', '만두'],
#  ['배달', '좋다'],
#  ['맛있다', '다만', '세트', '메뉴', '만두', '개수', '몇개', '표시'],
#  ['좋다'],
#  ['맛있다'],
#  ['맛있다'],
#  ['사진',
#   '없다',
#   '탕수육',
#   '소스',
#   '가지',
#   '소스',
#   '스프',
#   '가지',
#   '소스',
#   '필요',
#   '치도',
#   '전분',
#   '제대로',
#   '소스',
#   '다운',
#   '좋다',
#   '만두',
#   '중식',
#   '똑같다',
#   '자재',
#   '진짜',
#   '없다',
#   '만두',
#   '마나'],
#  ['짜장', '짬뽕', '탕수육', '하나', '진짜', '맛있다'],
#  ['맛있다', '배달', '좋다'],
#  ['맛있다',
#   '어머니',
#   '짬뽕',
#   '진짜',
#   '맛있다',
#   '배달',
#   '진짜',
#   '배달',
#   '사장',
#   '친절하다',
#   '기분',
#   '좋다',
#   '번창'],
#  ['배달', '빠르다', '좋다'],
#  ['예상', '시간', '뜨끈하다'],
#  ['아이', '음식', '탕수육', '자장면', '짬뽕', '맛있다'],
#  ['주소', '변경', '깜빡', '번거롭다', '빠르다', '맛있다'],
#  ['맛있다', '리뷰', '주문', '보답'],
#  ['맛있다', '쪼오끔', '아쉽다', '혼자'],
#  ['맛있다', '탕슉', '부드럽다'],
#  ['깔끔하다', '포장', '빠르다', '배달', '시간'],
#  ['배달', '따뜻하다'],
#  ['중식', '상하이', '맛있다', '깔끔하다'],
#  ['상하이', '맛있다', '급하다', '마음', '사진', '양도', '많다', '맛있다', '배달', '상하이', '주문', '번창'],
#  ['면발', '불어', '탕수육', '소스', '가지', '좋다', '눅눅하다', '아쉽다', '면발', '불어'],
#  ['동네',
#   '배달',
#   '단골',
#   '직접',
#   '가기',
#   '귀찮다',
#   '배달',
#   '짬뽕',
#   '국물',
#   '짜장',
#   '쵝오',
#   '진짜',
#   '엄지',
#   '찰기',
#   '없다',
#   '탄력',
#   '없다',
#   '국물',
#   '해물',
#   '찰나',
#   '탕수육',
#   '짧다',
#   '머리카락',
#   '사진'],
#  ['주문'],
#  [],
#  ['맛있다', '빠르다'],
#  ['짬뽕', '맛있다', '양도', '넉넉하다', '지역화폐', '결제', '안되다', '주문'],
#  ['가지', '소스', '탕슉'],
#  ['짜장면', '맛있다', '탕수육', '만두', '빠삭빠삭하', '맛있다'],
#  ['맛있다'],
#  ['동생', '주문', '동생', '조카', '리뷰', '좋다', '처음', '동생', '선물', '맛있다', '서비스', '감사'],
#  ['좋다', '봉투', '힘들다'],
#  ['맛있다', '많다', '배달', '빨르다'],
#  ['양은', '생각', '배달', '예상', '배달', '시간'],
#  ['좋다', '배달', '빠르다', '좋다', '처음', '주문', '만족하다'],
#  ['탕수육', '맛있다', '상하이', '다만', '배달', '바쁘다', '음식', '급하다', '볶음밥'],
#  ['예상',
#   '배달',
#   '시간',
#   '맛있다',
#   '세트',
#   '메뉴',
#   '만두',
#   '맛있다',
#   '간짜장',
#   '간이',
#   '조금',
#   '탕수육',
#   '식감',
#   '부드럽다',
#   '고기',
#   '쫄깃해',
#   '맜있'],
#  ['만족도',
#   '최상인',
#   '맛집',
#   '배달',
#   '원님',
#   '굉장하다',
#   '친절하다',
#   '짜장',
#   '짬봉',
#   '탕수육',
#   '맛있다',
#   '제일',
#   '탕수육',
#   '지금',
#   '맛있다'],
#  ['자장', '소스', '조금', '요청', '메모', '별도', '용기', '개인', '차라', '취향'],
#  ['진짜', '맛있다', '배달', '분만', '놀랏네'],
#  ['빠르다', '친절하다', '배달'],
#  ['배달', '빠르다', '맛있다'],
#  ['맛있다', '사진', '나중'],
#  [],
#  ['빠르다', '배송'],
#  ['일단',
#   '가격',
#   '부실하다',
#   '정도',
#   '정도',
#   '일단',
#   '마파두부',
#   '간이',
#   '짜장면',
#   '양으로',
#   '정도',
#   '탕수육',
#   '맛있다',
#   '정도',
#   '별로',
#   '원래',
#   '맛있다',
#   '방장'],
#  ['폭설',
#   '때문',
#   '배달',
#   '재택근무',
#   '없다',
#   '그냥',
#   '쟁반짜장',
#   '처음',
#   '맛있다',
#   '소스',
#   '남아',
#   '저녁',
#   '매장',
#   '위치'],
#  ['맛있다'],
#  ['맛있다'],
#  ['일단',
#   '일반',
#   '중국집',
#   '특별하다',
#   '짬뽕',
#   '탕수육',
#   '아이',
#   '맛있다',
#   '짜장',
#   '일반',
#   '단무지',
#   '삭함',
#   '쫀득',
#   '리뷰',
#   '좋다',
#   '주문',
#   '주문',
#   '시간',
#   '상하이',
#   '안녕'],
#  ['맛있다', '거기', '배달', '빠르다'],
#  ['단골', '맛있다'],
#  ['맛있다', '짬뽕', '알차다', '짜장면', '맛있다', '만두', '깜박', '대신', '짬뽕', '배기'],
#  ['맛있다', '중식', '탕수육', '굳다', '굳다'],
#  ['얼큰하다', '시원하다', '맛있다', '고추', '짜장', '속풀이', '짬뽕', '맛있다'],
#  ['맛있다', '배달', '안되다', '좋다'],
#  ['맛있다'],
#  ['배달', '빠르다', '양도', '많다', '다만', '조금', '불어', '아쉽다'],
#  ['도착', '탕수육', '기름', '많다'],
#  ['때문',
#   '배달',
#   '지연',
#   '이해',
#   '시간',
#   '조금',
#   '힘드다',
#   '일회용품',
#   '부탁드리다',
#   '그릇',
#   '친절하다',
#   '아쉬움'],
#  ['좋다'],
#  ['탕수육', '소스', '종류', '맛있다'],
#  ['삼선짬뽕', '맛있다', '삼선짜장', '맛있다', '탕수육', '바삭'],
#  ['괜찮다', '달라', '새벽', '덕분', '가족'],
#  ['맛있다', '탕수육', '맛있다', '아이', '맛있다'],
#  ['너뭄', '맛있다'],
#  ['처음',
#   '탕수육',
#   '맛있다',
#   '처음',
#   '음식',
#   '세트',
#   '메뉴',
#   '만두',
#   '없다',
#   '탕수육',
#   '만두',
#   '그릇',
#   '없다',
#   '아니다',
#   '탕수육',
#   '많다',
#   '보이',
#   '건가',
#   '처음',
#   '당황',
#   '스럽다',
#   '서비스',
#   '기분',
#   '별로',
#   '짜장면',
#   '원추',
#   '크게',
#   '차이',
#   '없다',
#   '추가',
#   '비교',
#   '확실하다',
#   '음식',
#   '좋다'],
#  ['맛있다'],
#  ['진짜', '많다', '탕수육', '맛있다', '쟁반짜장', '불맛', '맛있다'],
#  ['짜장', '짬뽕', '맛있다', '빠르다', '배송'],
#  ['배달', '신속하다', '짜장면', '좋다', '조금', '아쉽다', '탕수육', '부드럽다', '맛있다'],
#  ['세트', '메뉴', '맛있다', '새해', '첫날', '얼큰하다', '짬뽕', '쫄깃', '짜장면', '살살', '탕수육'],
#  ['맛있다', '탕수육', '소스', '맛있다', '짬뽕', '매콤', '맛있다'],
#  ['배달', '빠르다', '맛있다'],
#  ['맛있다', '좋다', '탕수육', '레시피', '탕수육', '부분', '조금', '아쉽다'],
#  [],
#  ['짬뽕'],
#  ['연말', '배달'],
#  ['짬뽕', '짜장면', '모두', '맛있다'],
#  ['맛있다'],
#  ['중국집', '최고', '맛집'],
#  ['맛있다', '기분', '좋다'],
#  ['시반',
#   '주문',
#   '음식',
#   '시가',
#   '훌쩍',
#   '도착',
#   '래서',
#   '짜장면',
#   '짬뽕',
#   '탕수육',
#   '눅눅하다',
#   '지금',
#   '최악',
#   '서비스',
#   '주신',
#   '만두',
#   '제일',
#   '맛있다',
#   '주문',
#   '아예',
#   '주문',
#   '맛없다',
#   '음식',
#   '차라리',
#   '소비자',
#   '맛있다',
#   '음식',
#   '배려'],
#  ['주문',
#   '배달',
#   '어이',
#   '없다',
#   '인내심',
#   '기다림',
#   '시간',
#   '분후',
#   '도착',
#   '짜장',
#   '식사',
#   '없다',
#   '짬뽕',
#   '보통',
#   '새롭다',
#   '중식',
#   '주문',
#   '크게',
#   '실패하다',
#   '원래',
#   '예정'],
#  ['사망', '직전', '착하다', '끝내주다', '바쁘다', '하니'],
#  ['진짜', '시간', '삼선', '짜장', '해물', '많다'],
#  ['맛있다', '한번'],
#  ['후기', '죄송하다', '맛있다', '변하다', '없다', '좋다', '중식', '상하이'],
#  ['포장', '깔끔하다', '엇요'],
#  ['빠르다', '배달', '최고', '중식'],
#  ['맛있다', '배달', '시간', '예상', '시간', '요청', '사항', '꼼꼼하다', '좋다', '상하이'],
#  ['중국집', '맛있다'],
#  ['음식',
#   '사진',
#   '없다',
#   '배달',
#   '시간',
#   '모두',
#   '만족하다',
#   '짬뽕',
#   '배기',
#   '주문',
#   '배기',
#   '아니다',
#   '오징어',
#   '야채',
#   '배기',
#   '주시',
#   '국물',
#   '시원',
#   '맛있다',
#   '짜장면',
#   '탕수육',
#   '맛있다',
#   '온라인수업',
#   '점심시간',
#   '아이',
#   '주문'],
#  ['맛있다'],
#  ['맛있다', '많다'],
#  ['배달', '문후', '분후', '전화', '그때', '출발', '탕수육', '배달', '중국집', '만족스럽다', '계속'],
#  ['맛있다', '쟁반짜장', '아이', '먹기', '쪼금', '맵다', '많다', '좋다', '주문'],
#  [],
#  ['배달', '주문', '많다', '그렇다', '조금', '덕분', '조금', '상태'],
#  ['배달', '빠르다', '맛있다'],
#  ['얼큰하다', '시원하다'],
#  ['짬뽕',
#   '소문',
#   '얼큰하다',
#   '짜장면',
#   '문안',
#   '탕수육',
#   '소스',
#   '가지',
#   '좋다',
#   '소스',
#   '건더기',
#   '많다',
#   '좋다'],
#  ['중식', '고추', '짜장', '처음', '맵다', '좋아하다', '한텐', '재료', '맛있다', '배달', '많다', '평소'],
#  ['배달', '잘못', '당황', '바로', '다시', '짬뽕', '국물', '시원하다'],
#  ['어마어마하다', '맛있다'],
#  ['배달', '분만', '아이', '배고프다', '바람', '사진', '이집', '짜장면', '맛있다', '자주'],
#  ['좋다', '많다', '배달', '빨르다', '새벽', '갑자기', '중국', '주문', '문자', '번창'],
#  ['짬뽕', '맛있다', '짜장', '맛있다', '점점', '맛있다'],
#  ['맛있다', '만족'],
#  ['짬뽕', '국물', '진국'],
#  ['양도', '많다', '맛있다'],
#  ['배달', '맛있다'],
#  ['콜라', '다소', '아쉽다', '맛있다'],
#  ['진짜', '맛있다'],
#  ['고맙다'],
#  ['빠르다', '배달', '요청', '사항', '맛있다'],
#  ['맛있다', '깔끔하다'],
#  ['진짜', '맛있다', '삿날', '짜장면', '처음', '맛집', '좋다'],
#  ['맛있다'],
#  ['양도', '많다', '맛있다'],
#  ['맛있다', '상상', '생각', '짜장면', '짬뽕', '탕수육', '맛있다'],
#  ['평범하다',
#   '중국음식',
#   '생명',
#   '속도',
#   '아니다',
#   '무오',
#   '중국음식',
#   '면류',
#   '완성',
#   '배달',
#   '운영',
#   '문제'],
#  ['탕수육',
#   '눅눅하다',
#   '딱딱하다',
#   '이렇다',
#   '아이덴티티',
#   '높다',
#   '탕수육',
#   '보기',
#   '힘들다',
#   '짜장면',
#   '급하다',
#   '느낌',
#   '짜장',
#   '첨가',
#   '밀가루',
#   '느낌',
#   '배달',
#   '분기',
#   '전화',
#   '다르다',
#   '더기',
#   '다리',
#   '전화',
#   '출발',
#   '약속',
#   '배달',
#   '맛없다',
#   '성의',
#   '없다',
#   '느낌',
#   '보임',
#   '점주',
#   '수업',
#   '관계',
#   '콜라',
#   '점줌',
#   '양은',
#   '그냥',
#   '그렇다',
#   '맛없다',
#   '많다',
#   '필요없다'],
#  ['맛있다'],
#  ['맛있다',
#   '짬뽕',
#   '맛있다',
#   '국물',
#   '진하다',
#   '짜장',
#   '소스',
#   '듬뿍',
#   '주시',
#   '탕수육',
#   '소스',
#   '가지',
#   '맛있다'],
#  ['배송', '빨르다', '처음', '맛있다', '탕수육', '소스', '다른', '종류'],
#  ['맛있다', '배달', '빠르다', '좋다', '탕수육', '소스', '차갑다'],
#  [],
#  ['맛있다', '양도', '쟁반짜장', '맛있다', '번창'],
#  ['맛있다', '먹엇어', '짬뽕', '칼칼하다', '괜찮다'],
#  ['짜장면', '불지', '맛있다', '리뷰', '사이다', '달라', '사장', '미워하다'],
#  ['맛있다', '중국음식', '배달', '이용', '좋다'],
#  ['불어', '아쉽다', '좋다'],
#  ['주말',
#   '점심',
#   '그렇다',
#   '아쉽다',
#   '전반',
#   '맛있다',
#   '짜장',
#   '다른',
#   '음식',
#   '살짝',
#   '싱겁다',
#   '다른',
#   '먹기',
#   '좋다',
#   '짬뽕',
#   '매콤',
#   '울면',
#   '처음',
#   '맛있다',
#   '만두',
#   '서비스'],
#  [],
#  ['좋다', '이용', '요즘', '바쁘다', '신지', '음식'],
#  ['빠르다', '배달', '감사', '맛있다'],
#  ['중국집', '무조건', '상하이', '맛집'],
#  ['요기',
#   '상하이',
#   '단골',
#   '라면',
#   '단골',
#   '음식',
#   '짜장',
#   '탕수육',
#   '만두',
#   '세트',
#   '평소',
#   '다르다',
#   '탕수육',
#   '소스',
#   '묽다',
#   '차갑다',
#   '탕수육',
#   '언제',
#   '차갑다',
#   '눅눅하다',
#   '뻣뻣하다',
#   '입맛',
#   '이제',
#   '상하이',
#   '주문'],
#  ['깔끔하다', '맛있다', '다시', '이용', '예정'],
#  ['맛있다', '서비스', '짬뽕', '국물', '최고'],
#  ['맛있다'],
#  ['빠르다'],
#  ['맛있다', '탕슉소스'],
#  ['시간', '그렇다', '맛있다'],
#  ['맛있다', '시간', '배달'],
#  ['배달', '예상', '시간', '빠르다', '맛있다'],
#  ['서비스'],
#  [],
#  ['신속', '배달', '따뜻하다', '음식', '배달'],
#  ['예전', '맛있다', '세트', '주문', '탕수육', '맛있다', '짜장', '짬뽕', '억지로', '먹음'],
#  ['짜장면'],
#  ['맛있다', '배달', '빠르다'],
#  ['상하이', '인덕', '원점', '최고'],
#  ['소스', '진하다', '괜찮다'],
#  ['맛있다'],
#  [],
#  ['맛있다', '리뷰', '이제', '리뷰'],
#  ['회사',
#   '회식',
#   '주문',
#   '우선',
#   '회사',
#   '일정',
#   '때문',
#   '배달',
#   '시간',
#   '지나',
#   '전혀',
#   '괜찮다',
#   '짜장',
#   '짬뽕',
#   '맛있다',
#   '탕수육',
#   '대자',
#   '추가',
#   '사진',
#   '맛있다',
#   '엄청나다',
#   '소스',
#   '가지',
#   '맛있다',
#   '기대',
#   '주문'],
#  ['맛있다'],
#  ['맛있다', '서비스', '만두', '맛있다'],
#  ['짬뽀', '국물', '서비스', '최고'],
#  ['배송', '빠르다', '좋다', '무엇', '좋다', '이용'],
#  ['맛있다', '짜장면', '탕수육', '바삭바삭하다', '소스', '가지', '즐거움'],
#  ['맛있다', '짬뽕', '해물', '없다'],
#  ['짬뽕',
#   '칼칼하다',
#   '해장',
#   '좋다',
#   '유부',
#   '콩나물',
#   '맛있다',
#   '짜장면',
#   '감칠맛',
#   '진짜',
#   '맛있다',
#   '삼선짜장',
#   '해물',
#   '없다',
#   '당황',
#   '진짜',
#   '맛있다'],
#  ['추천', '배달', '중국집', '아니다', '좋다', '점심'],
#  ['맛있다', '친절하다', '빠르다', '배달'],
#  ['배달', '맛있다'],
#  ['간짜장', '맛있다', '만두', '서비스', '굳다', '굳다', '볶음밥', '야채', '계란', '좀더', '많다', '좋다'],
#  ['만두', '짬뽕', '간짜장', '전분', '많다', '배달', '빨르다'],
#  ['배달', '빠르다', '맛있다'],
#  ['맛있다'],
#  ['동네', '중식', '배달', '제일', '낮다'],
#  ['속풀이', '짬뽕', '처음', '얼큰하다', '맛있다', '입맛', '그냥', '짬뽕', '맛있다', '간짜장'],
#  ['상하이',
#   '면류',
#   '맛있다',
#   '종류',
#   '위주',
#   '맛있다',
#   '짜장면',
#   '탕수육',
#   '맛있다',
#   '배달',
#   '배달',
#   '아저씨',
#   '친절하다',
#   '덕분',
#   '기분',
#   '좋다',
#   '주말',
#   '저녁',
#   '맛있다',
#   '주문',
#   '번창'],
#  ['짬뽕', '조금', '다르다', '유부', '어묵'],
#  ['맛있다',
#   '원래',
#   '처음',
#   '쟁반짜장',
#   '존맛',
#   '만두',
#   '얇다',
#   '알차다',
#   '맛있다',
#   '중국집',
#   '무조건',
#   '상하이',
#   '여러분'],
#  [],
#  ['맛있다'],
#  ['양도', '많다', '짜장', '짬뽕', '맛있다', '탕수육', '소스', '종류', '맛있다'],
#  ['배고프다'],
#  ['맛있다', '만두'],
#  ['배고프다',
#   '허겁지겁',
#   '바람',
#   '사진',
#   '여자친구',
#   '배달',
#   '오분',
#   '십분',
#   '거리',
#   '전화',
#   '배달',
#   '다시',
#   '달라',
#   '부탁드리다',
#   '요금',
#   '친절하다',
#   '배달',
#   '설정'],
#  ['다르다', '아쉽다'],
#  ['메뉴', '모두', '맛있다', '배달', '맛있다'],
#  ['배달',
#   '굳다',
#   '굳다',
#   '서비스',
#   '만두',
#   '맛있다',
#   '다만',
#   '짬뽕',
#   '콩나물',
#   '처음',
#   '짜장면',
#   '탕수육',
#   '맛있다',
#   '칠리소스',
#   '좋다'],
#  ['고추', '짜장', '맛있다'],
#  ['조금', '겨울', '감안', '이해', '음식', '센스', '오뎅', '귀엽다'],
#  ['양도', '많다', '맛있다'],
#  ['변하다', '맛집'],
#  ['탕수육', '아쉽다'],
#  ['음식', '맛있다', '아쉽다', '곱빼기', '추가', '주문'],
#  ['시간', '배달', '감사', '맛있다'],
#  ['양도', '많다', '맛있다', '소스'],
#  ['일만', '맛있다'],
#  ['맛있다', '짜장', '허겁지겁', '짜장'],
#  [],
#  ['어찌',
#   '음식',
#   '좋아하다',
#   '그렇다',
#   '배달',
#   '시간',
#   '시간',
#   '이후',
#   '전화하다',
#   '배달',
#   '서비스',
#   '만두',
#   '정작',
#   '탕슉',
#   '소스',
#   '다시',
#   '전화',
#   '이렇다',
#   '실수',
#   '좋다'],
#  ['양도', '많다'],
#  ['그냥', '그렇다'],
#  ['양도', '많다', '배달', '빠르다', '자장면', '살짝', '싱겁다'],
#  ['주문', '음식', '불어', '조금', '아쉽다', '배달', '일이', '양은', '넉넉하다', '배부르다'],
#  ['맛집', '발견', '자주'],
#  ['음식',
#   '주문',
#   '음식',
#   '수령',
#   '탕수육',
#   '짜장면',
#   '뿔뿔',
#   '사장',
#   '시큰둥',
#   '배달',
#   '아저씨',
#   '시큰둥',
#   '리뷰',
#   '이벤트',
#   '아깝다',
#   '사이다',
#   '도로'],
#  ['탕수육',
#   '튀김',
#   '눅눅하다',
#   '자체',
#   '나쁘다',
#   '소스',
#   '굉장하다',
#   '걸죽',
#   '추천',
#   '소스',
#   '종류',
#   '짜장',
#   '소스',
#   '별루',
#   '짬뽕',
#   '괜찮다'],
#  ['국물', '넉넉하다', '달라', '요청', '그릇', '사장'],
#  ['아이', '없다', '남편', '냄새'],
#  ['짜장면', '불지', '좋다', '탕수육', '맛있다'],
#  ['배달', '빠르다', '맛있다'],
#  ['탕수육', '돼지고기', '냄새'],
#  ['좋다', '자주', '먹음'],
#  ['맛있다', '배달', '빠르다', '좋다'],
#  ['짬뽕', '국물', '맛있다'],
#  ['맛있다'],
#  ['아이', '맛있다', '순식간', '뚝딱', '수고'],
#  ['양도', '많다', '맛있다'],
#  ['예상',
#   '주문',
#   '시간',
#   '배달',
#   '시간',
#   '조리',
#   '시간',
#   '면도',
#   '탕수육',
#   '눅눅하다',
#   '시간',
#   '시간',
#   '배달',
#   '안되다',
#   '경우',
#   '주문',
#   '시간',
#   '변경'],
#  ['맛있다'],
#  ['좀뿔'],
#  ['처음', '맛있다', '서비스', '만두', '맛있다'],
#  ['단골',
#   '이상하다',
#   '탕수육',
#   '맛있다',
#   '부분',
#   '냄새',
#   '부분',
#   '냄새',
#   '비율',
#   '정도',
#   '냄새',
#   '원인',
#   '야하다'],
#  ['짬뽕', '짜장', '모두', '맛있다'],
#  ['짜장면', '좋다', '아쉽다'],
#  ['맛있다'],
#  ['짜장면', '상하이', '맛있다'],
#  ['양도', '많다'],
#  ['중국집', '평타', '얼마', '새롭다', '망하다'],
#  ['배달', '면도', '불어', '실망'],
#  ['탕수육', '맛있다'],
#  ['양도',
#   '많다',
#   '맛있다',
#   '쟁반짜장',
#   '용기',
#   '예전',
#   '넓다',
#   '쟁반짜장',
#   '고추기름',
#   '약간',
#   '매콤',
#   '짬뽕',
#   '국물',
#   '해산물',
#   '많다'],
#  ['맛있다'],
#  ['탕수육', '만두', '맛있다', '양도', '많다', '짜장면', '양파', '춘장', '별로'],
#  ['간짜장', '맛있다', '가장', '좋다', '포인트'],
#  ['맛있다', '새벽', '배달', '가능하다', '좋다'],
#  ['짜장', '불지', '배달', '서비스', '좋다'],
#  ['맛있다', '번창'],
#  ['배달', '맛있다'],
#  ['빠르다', '배달', '맛있다'],
#  ['처음', '진짜', '양도', '많다', '통통하다', '맛있다'],
#  ['정시',
#   '요청',
#   '사항',
#   '꼼꼼하다',
#   '친절하다',
#   '기분',
#   '좋다',
#   '제육',
#   '진짜',
#   '한번',
#   '제육',
#   '맛있다',
#   '제육',
#   '한번'],
#  ['자주', '쿠폰'],
#  ['맛있다', '친절하다', '빠르다', '배달'],
#  ['맛있다'],
#  ['진짜', '솔직하다', '짜장면', '맛있다', '지금', '지역', '짜장면', '맛있다', '짜장', '짜장면', '추천'],
#  ['맛있다', '소스', '가지', '좋다', '배달', '빠르다'],
#  ['맛있다'],
#  ['시간', '짬뽕', '맛있다', '국물', '얼큰하다', '맛있다'],
#  [],
#  ['배달', '빠르다'],
#  ['맛있다'],
#  ['배달',
#   '빨르다',
#   '탕수육',
#   '딱딱하다',
#   '짜장',
#   '짬뽕',
#   '단편',
#   '이구',
#   '볶음밥',
#   '괜찮다',
#   '짜장',
#   '소스',
#   '삐벼',
#   '먹기',
#   '양은',
#   '좋다',
#   '전체',
#   '나쁘다',
#   '배고프다',
#   '후다닥',
#   '사진'],
#  ['맛있다'],
#  ['맛있다', '변하다', '없다', '굿굿'],
#  ['맛있다', '어유', '많다', '아유', '탕슉', '허유'],
#  ['대체로', '맛있다', '짬뽕', '조금', '얼큰하다', '좋다', '써비'],
#  ['우리',
#   '식구',
#   '상하이',
#   '광팬',
#   '시간',
#   '전화하다',
#   '분만',
#   '시간',
#   '배고프다',
#   '우리',
#   '아빠',
#   '머리',
#   '나시',
#   '음식',
#   '나나',
#   '와중',
#   '쿠폰'],
#  ['바쁘다', '시간', '맛있다'],
#  [],
#  ['탕수육'],
#  ['사진', '깜빡', '맛있다', '배달', '빠르다', '양도', '적당하다', '깔끔하다'],
#  ['맛있다'],
#  ['볶음밥', '대체로', '맛있다'],
#  ['맛있다', '배달', '예상', '시간', '짬뽕', '국물', '좋다'],
#  ['자주', '면도', '간짜장', '탕수육', '만두', '모두', '조리', '한지', '오레', '시간', '음식', '다시'],
#  ['짬뽕', '고기', '짬뽕', '기름기', '없다', '맛있다', '쟁반짜장', '맛있다', '없다', '그대로', '부탁드리다'],
#  ['맛있다', '고추', '잡채', '주문', '꽃빵', '아쉬움'],
#  ['가격', '착하다', '좋다', '후다닥', '바람', '사진', '없다'],
#  ['짜장면', '불지', '맛있다'],
#  ['실망', '감동'],
#  ['음식',
#   '평소',
#   '가족',
#   '모임',
#   '주문',
#   '많다',
#   '경우',
#   '배달',
#   '그렇다',
#   '화가',
#   '듯이',
#   '행동',
#   '분위기',
#   '살벌하다',
#   '압박',
#   '주어',
#   '손님',
#   '동성',
#   '얘기',
#   '이렇다',
#   '처음',
#   '반갑다',
#   '맞이',
#   '배달',
#   '아저씨',
#   '기분',
#   '나쁘다',
#   '화가',
#   '모습',
#   '음식',
#   '기억',
#   '모습',
#   '각인',
#   '대량',
#   '주문',
#   '절대',
#   '추천',
#   '좋다',
#   '글쎄요'],
#  ['배달', '서비스', '감사'],
#  ['매번', '맛있다', '요리', '포장', '깔끔하다', '보장'],
#  ['쟁반짜장', '인분', '인분', '정도', '기준'],
#  ['맛있다'],
#  ['시간', '몹시', '많다', '몇번', '많다'],
#  ['맛있다', '빠르다', '배송', '좋다'],
#  [],
#  ['맛있다', '배달', '빠르다', '맛있다', '배달', '신분', '매우', '친절하다'],
#  ['배달', '원님', '친절하다', '음식', '맛있다'],
#  ['리뷰', '작성'],
#  ['맵다', '매콤'],
#  ['많다', '좋다'],
#  ['한양'],
#  ['배달', '빠르다', '좋다'],
#  ['최고', '안양'],
#  ['볶음밥', '맛있다', '봉지', '포장', '불편하다'],
#  ['지역', '중국집', '상하이'],
#  [],
#  ['맛있다'],
#  ['배달', '빠르다', '시간'],
#  ['은감', '나름', '맛있다'],
#  ['빠르다', '친절하다', '안전하다', '배달', '상태', '좋다'],
#  ['맛있다', '점점', '맛있다'],
#  ['맛있다', '다시', '주로', '짬뽕', '쟁반짜장', '맛있다', '자주'],
#  ['괜찮다', '많다', '맛있다', '소스', '대신', '짬뽕', '국물', '좋다'],
#  ['쟁반짜장', '맛있다', '주문'],
#  ['양도', '주시', '맛있다', '주문'],
#  ['양도',
#   '많다',
#   '맛있다',
#   '짬뽕',
#   '진짜',
#   '해지',
#   '느낌',
#   '해장',
#   '맛있다',
#   '배달',
#   '예정',
#   '정도',
#   '오시',
#   '배달',
#   '친절하다',
#   '좋다',
#   '계속'],
#  ['잡채', '뻑뻑', '맛있다'],
#  ['배달', '예상', '음식', '맛있다'],
#  ['빠르다', '배달', '음식'],
#  ['배달', '금방', '맛있다'],
#  ['쫌늦게와', '맛있다', '양도', '많다', '고기', '많다', '맛있다'],
#  ['배달', '빠르다', '짜장면', '아이', '허겁지겁', '사진'],
#  ['단골', '일회용', '식기', '용기', '아깝다', '상황', '상황'],
#  ['짬뽕', '깔끔하다', '쟁반짜장', '진짜', '맛있다', '소스', '정도', '맛있다'],
#  ['맛있다'],
#  [],
#  ['국물', '짜장면', '좋다', '만두'],
#  ['자취', '중국집', '맛집'],
#  ['탕수육', '맛있다'],
#  [],
#  ['배달', '빠르다', '맛있다'],
#  ['짜장면', '맛있다'],
#  ['배달', '포장', '깔끔하다', '짜장', '짬뽕', '탕수육', '맛있다'],
#  ['배달', '업체'],
#  ['괜찮다', '서비스', '만두', '맛있다'],
#  [],
#  ['탕수육', '눅눅하다', '소스', '짜장', '짬뽕', '맛있다'],
#  ['맛있다', '중식'],
#  ['짬뽕',
#   '짜장',
#   '맛있다',
#   '탕수육',
#   '바삭바삭하다',
#   '왓구',
#   '배달',
#   '이후',
#   '배달',
#   '예상',
#   '소요',
#   '시간',
#   '좋다'],
#  ['맛있다'],
#  ['생각', '음식', '좋다', '집사람', '깜빡', '바람', '도중', '맛있다', '번창'],
#  ['맛있다', '탕수육'],
#  ['평소', '맛있다', '간짜장', '불어'],
#  ['진짜', '배송', '맛있다', '불리', '이벤트', '콜라'],
#  ['양도', '많다', '맛있다'],
#  ['배달', '예상', '시간', '맛있다'],
#  ['세번',
#   '맛있다',
#   '두번째',
#   '망하다',
#   '재료',
#   '재탕',
#   '느낌',
#   '세번',
#   '마지막',
#   '기대',
#   '뭔가',
#   '배송',
#   '빠르다',
#   '짜장면',
#   '사진',
#   '원래',
#   '그릇',
#   '모양',
#   '심하다',
#   '볶음밥',
#   '계란',
#   '조금',
#   '재료',
#   '어어',
#   '부실하다',
#   '배송',
#   '만두',
#   '이벤트',
#   '좋다',
#   '처음',
#   '찾기',
#   '힘드다'],
#  ['맛있다', '양도', '많다'],
#  ['맛있다', '서비스', '만두'],
#  ['인기', '많다', '그렇다', '점심', '시간', '시간'],
#  ['맛있다'],
#  ['처음', '맛있다', '아이', '맛있다', '그릇', '뚝딱'],
#  ['짜장면', '맛있다', '탕수육', '칠리소스', '주니', '좋다', '탕수육', '만두', '바싹', '주심', '좋다'],
#  ['요즘', '중국집', '맛있다'],
#  ['음식',
#   '서비스',
#   '주신',
#   '만두',
#   '음식',
#   '맛있다',
#   '배달',
#   '심하다',
#   '불어',
#   '불지',
#   '맛있다',
#   '바쁘다',
#   '시간',
#   '피해',
#   '주문',
#   '괜찮다'],
#  ['배달', '빠르다', '좋다'],
#  ['맛있다'],
#  [],
#  ['아이', '맛있다'],
#  ['배달', '기사', '친절하다', '빠르다', '맛있다', '탕슉', '소스', '센스'],
#  ['짜장면', '불어', '양념'],
#  ['맛있다'],
#  ['맛있다'],
#  ['탕수육', '조금', '눅눅하다', '짬뽕', '불맛', '강하다', '좋다', '배부르다'],
#  ['배달',
#   '생각',
#   '빨르다',
#   '자장면',
#   '먼저',
#   '불어',
#   '아쉽다',
#   '탕수육',
#   '쫄깃',
#   '생각',
#   '소스',
#   '살짝',
#   '좋다'],
#  ['배달', '친절하다'],
#  ['존맛', '먹음'],
#  ['아니다', '정도', '양도', '많다', '어후', '사장', '변하다'],
#  ['상하이', '쟁반짜장', '진짜', '맛있다', '리얼'],
#  ['배달', '무엇', '양도', '불리'],
#  ['빠르다', '많다', '맛있다'],
#  ['배달', '친절하다', '기대하다', '모두', '괜찮다', '배달', '불지', '맛있다'],
#  ['배달', '빠르다', '짐해', '짜장면', '짬뽕', '맛있다', '짬뽕', '콩나물', '국물', '시원하다'],
#  ['습니'],
#  ['좋다', '짬뽕', '얼큰하다', '맛있다', '안남', '기고', '배달', '그릇', '깔끔하다', '주문'],
#  ...]

# %%
# 모델 학습 테스트

model = tp.LDAModel(k=16, alpha=0.1, eta=0.01, min_cf=20,tw=tp.TermWeight.PMI, rm_top=1)
for i, line in enumerate(data_word):
    if not line:
        line.append(" ")
    model.add_doc(line) 
    if i % 10 == 0: print('Document #{} has been loaded'.format(i))
 
model.train(0)
print('Total docs:', len(model.docs))
print('Total words:', model.num_words)
print('Vocab size:', model.num_vocabs)
 
 
for i in range(1500):
    print('Iteration {}\tLL per word: {}'.format(i, model.ll_per_word))
    model.train(1)
 
for i in range(model.k):
    res = model.get_topic_words(i, top_n=10)
    print('Topic #{}'.format(i), end='\t')
    
    print(', '.join(w+':'+ str(p) for w, p in res))
# Out:
# Document #0 has been loaded
# Document #10 has been loaded
# Document #20 has been loaded
# Document #30 has been loaded
# Document #40 has been loaded
# Document #50 has been loaded
# Document #60 has been loaded
# Document #70 has been loaded
# Document #80 has been loaded
# Document #90 has been loaded
# Document #100 has been loaded
# Document #110 has been loaded
# Document #120 has been loaded
# Document #130 has been loaded
# Document #140 has been loaded
# Document #150 has been loaded
# Document #160 has been loaded
# Document #170 has been loaded
# Document #180 has been loaded
# Document #190 has been loaded
# Document #200 has been loaded
# Document #210 has been loaded
# Document #220 has been loaded
# Document #230 has been loaded
# Document #240 has been loaded
# Document #250 has been loaded
# Document #260 has been loaded
# Document #270 has been loaded
# Document #280 has been loaded
# Document #290 has been loaded
# Document #300 has been loaded
# Document #310 has been loaded
# Document #320 has been loaded
# Document #330 has been loaded
# Document #340 has been loaded
# Document #350 has been loaded
# Document #360 has been loaded
# Document #370 has been loaded
# Document #380 has been loaded
# Document #390 has been loaded
# Document #400 has been loaded
# Document #410 has been loaded
# Document #420 has been loaded
# Document #430 has been loaded
# Document #440 has been loaded
# Document #450 has been loaded
# Document #460 has been loaded
# Document #470 has been loaded
# Document #480 has been loaded
# Document #490 has been loaded
# Document #500 has been loaded
# Document #510 has been loaded
# Document #520 has been loaded
# Document #530 has been loaded
# Document #540 has been loaded
# Document #550 has been loaded
# Document #560 has been loaded
# Document #570 has been loaded
# Document #580 has been loaded
# Document #590 has been loaded
# Document #600 has been loaded
# Document #610 has been loaded
# Document #620 has been loaded
# Document #630 has been loaded
# Document #640 has been loaded
# Document #650 has been loaded
# Document #660 has been loaded
# Document #670 has been loaded
# Document #680 has been loaded
# Topic #15	배달:0.1518431305885315, 빠르다:0.12773437798023224, 좋다:0.08176036179065704, 양도:0.06899673491716385, 많다:0.0661444365978241, 친절하다:0.053096089512109756, 빨르다:0.04745950922369957, 시간:0.03433915600180626, 괜찮다:0.027528459206223488, 음식:0.026740584522485733

# %% [markdown]
# # 일관성 계산

# %%
def compute_coherence_values(data_word ,limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = tp.LDAModel(k=num_topics, alpha=0.1, eta=0.01, min_cf=20,tw=tp.TermWeight.PMI, rm_top=1)
        for i, line in enumerate(data_word):
            if not line:
                line.append(" ")
            model.add_doc(line)
        model.train(1500) # 학습 정도
        model_list.append(model)
        coherence_model = coherence.Coherence(model, coherence='c_v', window_size=0, targets=None, top_n=10, eps=1e-12, gamma=1.0)
        coherence_values.append(coherence_model.get_score())
    return model_list, coherence_values

# %%
# 일관성 계산 테스트
from tomotopy import coherence
coherence_model = coherence.Coherence(model, coherence='c_v', window_size=0, targets=None, top_n=10, eps=1e-12, gamma=1.0)
coherence_model.get_score()
# Out:
# 0.5761952466797085

# %%
# 토픽 수를 14~ 25 로 해서 각각의 모델과 일관성 점수를 계산한 리스트 얻기 
from tomotopy import coherence
model_list, coherence_values = compute_coherence_values(data_word=data_word, start=14, limit=25, step=2)

# %%
# 최적의 모델 얻기
limit=25; start=14; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

# 최적의 모델
optimal_model = model_list[model_list_num]
# Out:
# Num Topics = 14  has Coherence Value of 0.5666960178741387
# Num Topics = 16  has Coherence Value of 0.5601019229739904
# Num Topics = 18  has Coherence Value of 0.5712031256407499
# Num Topics = 20  has Coherence Value of 0.5666951548308135
# Num Topics = 22  has Coherence Value of 0.5558717583052135
# Num Topics = 24  has Coherence Value of 0.5478932381297151

# %%
for i in range(optimal_model.k):
    res = optimal_model.get_topic_words(i, top_n=10)
    print('Topic #{}'.format(i), end='\t')
    #print(', '.join(w for w, p in res))
    print(', '.join(w+':'+ str(p) for w, p in res))
# Out:
# Topic #0	리뷰:0.06581462174654007, 만두:0.041614335030317307, 이벤트:0.03986998274922371, 짬뽕:0.025652924552559853, 짜장면:0.024610761553049088, 주문:0.023129422217607498, 만족:0.022747252136468887, 서비스:0.022747192531824112, 배달:0.02232983335852623, 괜찮다:0.02169489488005638
# Topic #1	굳다:0.30070242285728455, 사진:0.11010444909334183, 깜빡:0.0921492651104927, 번창:0.05905796214938164, 배고프다:0.05330663546919823, 상하이:0.05044722929596901, 많다:0.0483270138502121, 양도:0.04676007106900215, 급하다:0.04505987465381622, 진짜:0.04087330773472786
# Topic #2	기분:0.1528807133436203, 사람:0.15064360201358795, 그냥:0.12660038471221924, 먹기:0.11761032044887543, 쿠폰:0.10961844027042389, 그렇다:0.10685716569423676, 나쁘다:0.09823422133922577, 금방:0.07945482432842255, 힘들다:0.029438627883791924, 양파:0.01138984877616167
# Topic #14	탕수육:0.05037165805697441, 소스:0.04112356901168823, 짬뽕:0.035479672253131866, 좋다:0.03221937641501427, 짜장면:0.02719009853899479, 짜장:0.022614985704421997, 바삭:0.021729782223701477, 조금:0.020496757701039314, 가지:0.01920853555202484, 진짜:0.018284790217876434
# Topic #15	 :0.9977588653564453, 시간:1.206507113238331e-05, 보통:1.1987638572463766e-05, 짜장:1.1975768757110927e-05, 불어:1.197011715703411e-05, 좋다:1.1948639439651743e-05, 전화:1.1929987522307783e-05, 예상:1.188759779324755e-05, 짬뽕:1.1876293683599215e-05, 아이:1.1875163181684911e-05
# Topic #16	최고:0.0809314027428627, 만족하다:0.07637491077184677, 자주:0.07637390494346619, 무난:0.06920701265335083, 서비스:0.06610416620969772, 가격:0.06419733166694641, 아이:0.062257591634988785, 국물:0.06032375246286392, 쿠폰:0.056888461112976074, 주시:0.053647760301828384
# Topic #17	배달:0.1969117373228073, 빠르다:0.18657876551151276, 친절하다:0.10025444626808167, 좋다:0.0688178688287735, 음식:0.053996846079826355, 분도:0.04190952330827713, 시간:0.04190067946910858, 기분:0.029059497639536858, 예상:0.02790467068552971, 기사:0.025480618700385094

# %% [markdown]
# # 토픽 레이블링

# %%
# 주제 단어 후보군 뽑기
extractor = tp.label.PMIExtractor(min_cf=15, min_df=5,min_len = 2, max_len=20, max_cand=10000)
cands = extractor.extract(optimal_model)

labels_per_topic = []

labeler = tp.label.FoRelevance(optimal_model, cands, min_df=5, smoothing=0.01, mu=0.25)
for k in range(optimal_model.k):
    print("== Topic #{} ==".format(k))
    print("Labels:", ', '.join(label for label, score in labeler.get_topic_labels(k, top_n=5)))
    labels_per_topic.append(labeler.get_topic_labels(k, top_n=2)[0][0]+' + '+labeler.get_topic_labels(k, top_n=2)[1][0])
    for word, prob in optimal_model.get_topic_words(k, top_n=10):
        print(word, prob, sep='\t')
    print()
# Out:
# == Topic #0 ==
# Labels: 리뷰 이벤트, 짬뽕 국물, 세트 메뉴, 서비스 주신, 주신 만두
# 리뷰	0.06581462174654007
# 만두	0.041614335030317307
# 이벤트	0.03986998274922371
# 짬뽕	0.025652924552559853
# 짜장면	0.024610761553049088
# 주문	0.023129422217607498
# 만족	0.022747252136468887
# 서비스	0.022747192531824112
# 배달	0.02232983335852623
# 괜찮다	0.02169489488005638
#
# == Topic #1 ==
# Labels: 양도 많다, 맛있다 짜장면, 예상 시간, 맛있다 만두, 만두 맛있다
# 굳다	0.30070242285728455
# 사진	0.11010444909334183
# 깜빡	0.0921492651104927
# 번창	0.05905796214938164
# 배고프다	0.05330663546919823
# 상하이	0.05044722929596901
# 많다	0.0483270138502121
# 양도	0.04676007106900215
# 급하다	0.04505987465381622
# 진짜	0.04087330773472786
#
# == Topic #2 ==
# Labels: 소스 종류, 배달 음식, 짜장 소스, 떡볶이 맛있다, 음식 맛있다
# 기분	0.1528807133436203
# 사람	0.15064360201358795
# 그냥	0.12660038471221924
# 먹기	0.11761032044887543
# 쿠폰	0.10961844027042389
# 그렇다	0.10685716569423676
# 나쁘다	0.09823422133922577
# 금방	0.07945482432842255
# 힘들다	0.029438627883791924
# 양파	0.01138984877616167
#
# == Topic #3 ==
# Labels: 짜장 소스, 탕수육 고기, 세트 메뉴, 짬뽕 국물, 탕수육 소스
# 탕수육	0.030428702011704445
# 짜장	0.029197368770837784
# 고기	0.02756735123693943
# 없다	0.027452688664197922
# 간짜장	0.026914866641163826
# 짬뽕	0.026034507900476456
# 많다	0.02393130585551262
# 그냥	0.023883922025561333
# 아쉽다	0.023196009919047356
# 불어	0.022116955369710922
#
# == Topic #4 ==
# Labels: 양도 많다, 양도 많다 배달, 많다 배달, 주문 배달, 맛있다 양도
# 배달	0.10389146953821182
# 양도	0.09507949650287628
# 많다	0.09392279386520386
# 빠르다	0.08847495168447495
# 좋다	0.06318623572587967
# 빨르다	0.05313504487276077
# 배송	0.03521047160029411
# 괜찮다	0.03442525491118431
# 진짜	0.02472967468202114
# 시간	0.024182477965950966
#
# == Topic #5 ==
# Labels: 배달 시간, 시간 시간, 예상 시간, 세트 메뉴, 주문 배달
# 시간	0.08106004446744919
# 전화	0.045858707278966904
# 배달	0.03323100507259369
# 도착	0.032212335616350174
# 주문	0.028877882286906242
# 배고프다	0.027762366458773613
# 없다	0.026495132595300674
# 음식	0.02609620802104473
# 분만	0.025648368522524834
# 사진	0.02527596615254879
#
# == Topic #6 ==
# Labels: 요청 사항, 리뷰 이벤트, 배달 분도, 맛있다 짬뽕 국물, 짬뽕 국물
# 요청	0.2855876684188843
# 사항	0.22846898436546326
# 달라	0.08724385499954224
# 국물	0.03502008318901062
# 양파	0.034592367708683014
# 리뷰	0.033271756023168564
# 짬뽕	0.02973952144384384
# 부탁드리다	0.029447151347994804
# 단무지	0.028770029544830322
# 예상	0.023053312674164772
#
# == Topic #7 ==
# Labels: 짜장 떡볶이, 떡볶이 맛있다, 서비스 주신, 리뷰 이벤트, 진짜 맛있다
# 떡볶이	0.1141275018453598
# 단계	0.07541599124670029
# 짜장	0.06357449293136597
# 맵다	0.060004450380802155
# 꽃빵	0.04892205446958542
# 연유	0.042448680847883224
# 돈까스	0.039316482841968536
# 이벤트	0.03101435676217079
# 리뷰	0.030171135440468788
# 처음	0.025868644937872887
#
# == Topic #8 ==
# Labels: 최고 최고, 탕수육 소스, 서비스 주신 만두, 맛있다 짜장면, 사진 없다
# 최고	0.2057628333568573
# 중국집	0.10692994296550751
# 중식	0.10122018307447433
# 제일	0.0766393169760704
# 동네	0.06890062987804413
# 주문	0.06034975126385689
# 맛집	0.05605704337358475
# 북경	0.054797179996967316
# 상하이	0.046818315982818604
# 단골	0.04608859494328499
#
# == Topic #9 ==
# Labels: 진짜 맛있다, 차돌 짬뽕, 짬뽕 진짜, 리뷰 이벤트, 맛있다 주문
# 짜장	0.08850540220737457
# 굿굿	0.08714237809181213
# 간짜장	0.08014035224914551
# 단골	0.0730302631855011
# 중국음식	0.07169610261917114
# 차돌	0.06644625216722488
# 진짜	0.04875950515270233
# 짬뽕	0.046612273901700974
# 최고	0.043172940611839294
# 떡볶이	0.042177464812994
#
# == Topic #10 ==
# Labels: 서비스 주신 만두, 주신 만두, 서비스 주신, 만두 맛있다, 맛있다 서비스
# 상하이	0.18021242320537567
# 서비스	0.17694644629955292
# 만두	0.1714898645877838
# 주신	0.05372484028339386
# 짜장면	0.05063211917877197
# 좋다	0.04787224531173706
# 안나	0.04653434827923775
# 냄새	0.03783580660820007
# 고기	0.03191522881388664
# 탕수육	0.03184576332569122
#
# == Topic #11 ==
# Labels: 맛있다 짬뽕, 짬뽕 국물, 주신 만두, 서비스 주신 만두, 서비스 주신
# 짬뽕	0.10027360916137695
# 국물	0.06493867933750153
# 짜장	0.06464430689811707
# 삼선	0.061650343239307404
# 없다	0.060391295701265335
# 잡채	0.05868767946958542
# 우동	0.057540226727724075
# 간짜장	0.049849338829517365
# 해물	0.04372509941458702
# 자장면	0.04034482315182686
#
# == Topic #12 ==
# Labels: 짜장 소스, 탕수육 고기, 짜장 탕수육, 탕수육 소스, 서비스 주신 만두
# 탕수육	0.057351671159267426
# 간짜장	0.04467679187655449
# 냄새	0.0411209799349308
# 딱딱하다	0.03477974608540535
# 평소	0.03136187046766281
# 그렇다	0.031172463670372963
# 볶음밥	0.029984254390001297
# 다시	0.029954006895422935
# 기름	0.029640544205904007
# 저번	0.023636847734451294
#
# == Topic #13 ==
# Labels: 깔끔하다 맛있다, 맛있다 자주, 쟁반짜장 맛있다, 양도 많다, 짬뽕 탕수육
# 깔끔하다	0.16042475402355194
# 자주	0.1279303878545761
# 포장	0.12353160977363586
# 번창	0.10190936177968979
# 주문	0.07435319572687149
# 이용	0.06687291711568832
# 쟁반짜장	0.06252793967723846
# 중식	0.058447401970624924
# 좋다	0.052043624222278595
# 다시	0.052016496658325195
#
# == Topic #14 ==
# Labels: 짬뽕 국물, 탕수육 소스, 맛있다 탕수육, 소스 가지, 세트 메뉴
# 탕수육	0.05037165805697441
# 소스	0.04112356901168823
# 짬뽕	0.035479672253131866
# 좋다	0.03221937641501427
# 짜장면	0.02719009853899479
# 짜장	0.022614985704421997
# 바삭	0.021729782223701477
# 조금	0.020496757701039314
# 가지	0.01920853555202484
# 진짜	0.018284790217876434
#
# == Topic #15 ==
# Labels: 최고 최고, 양도 적당하다, 차돌 짬뽕, 짜장 짬뽕 맛있다, 양은 많다
#  	0.9977588653564453
# 시간	1.206507113238331e-05
# 보통	1.1987638572463766e-05
# 짜장	1.1975768757110927e-05
# 불어	1.197011715703411e-05
# 좋다	1.1948639439651743e-05
# 전화	1.1929987522307783e-05
# 예상	1.188759779324755e-05
# 짬뽕	1.1876293683599215e-05
# 아이	1.1875163181684911e-05
#
# == Topic #16 ==
# Labels: 탕수육 맛있다, 맛있다 짜장면, 사진 없다, 짜장면 탕수육, 탕수육 튀김
# 최고	0.0809314027428627
# 만족하다	0.07637491077184677
# 자주	0.07637390494346619
# 무난	0.06920701265335083
# 서비스	0.06610416620969772
# 가격	0.06419733166694641
# 아이	0.062257591634988785
# 국물	0.06032375246286392
# 쿠폰	0.056888461112976074
# 주시	0.053647760301828384
#
# == Topic #17 ==
# Labels: 빠르다 배달, 기분 좋다, 음식 맛있다, 빠르다 맛있다, 시간 빠르다
# 배달	0.1969117373228073
# 빠르다	0.18657876551151276
# 친절하다	0.10025444626808167
# 좋다	0.0688178688287735
# 음식	0.053996846079826355
# 분도	0.04190952330827713
# 시간	0.04190067946910858
# 기분	0.029059497639536858
# 예상	0.02790467068552971
# 기사	0.025480618700385094

# %%
labels_per_topic
# Out:
# ['리뷰 이벤트 + 짬뽕 국물',
#  '양도 많다 + 맛있다 짜장면',
#  '소스 종류 + 배달 음식',
#  '짜장 소스 + 탕수육 고기',
#  '양도 많다 + 양도 많다 배달',
#  '배달 시간 + 시간 시간',
#  '요청 사항 + 리뷰 이벤트',
#  '짜장 떡볶이 + 떡볶이 맛있다',
#  '최고 최고 + 탕수육 소스',
#  '진짜 맛있다 + 차돌 짬뽕',
#  '서비스 주신 만두 + 주신 만두',
#  '맛있다 짬뽕 + 짬뽕 국물',
#  '짜장 소스 + 탕수육 고기',
#  '깔끔하다 맛있다 + 맛있다 자주',
#  '짬뽕 국물 + 탕수육 소스',
#  '최고 최고 + 양도 적당하다',
#  '탕수육 맛있다 + 맛있다 짜장면',
#  '빠르다 배달 + 기분 좋다']

# %% [markdown]
# # 리뷰별 토픽 할당

# %%
def format_topics_sentences(ldamodel=optimal_model):
    new_doc = ldamodel.docs
    sent_topics_df = pd.DataFrame()
    
    for i in range(len(data_word)):
        topics = new_doc[i].get_topics()
        for j, (topic_num, prop_topic) in enumerate(topics):
            if j == 0:
                wp = optimal_model.get_topic_words(topic_num, top_n=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                topic_label = labels_per_topic[topics[j][0]]
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4),topic_label, topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution','Topic_Label', 'Topic_Keywords']
    sent_topics_df = pd.concat([sent_topics_df, searched_reviews['지점명'],searched_reviews['유저'],searched_reviews['메뉴'],searched_reviews['리뷰'],searched_reviews['총점'],searched_reviews['맛'],searched_reviews['양'],searched_reviews['배달'],searched_reviews['시간']], axis=1)
    
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model)
df_topic_review = df_topic_sents_keywords.reset_index()
df_topic_review.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib','Topic_Label' ,'Keywords', '지점명','유저', '메뉴','리뷰','총점','맛','양','배달','시간' ]
df_topic_review
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib       Topic_Label  \
# 0               0             3.0              0.4812    짜장 소스 + 탕수육 고기
# 1               1            14.0              0.2374    짬뽕 국물 + 탕수육 소스
# 2               2            15.0              0.9728   최고 최고 + 양도 적당하다
# 3               3            14.0              0.9932    짬뽕 국물 + 탕수육 소스
# 4               4             4.0              0.9798  양도 많다 + 양도 많다 배달
# ...           ...             ...                 ...               ...
# 4652         4652             2.0              0.9892     소스 종류 + 배달 음식
# 4653         4653             4.0              0.9816  양도 많다 + 양도 많다 배달
# 4654         4654             9.0              0.9914    진짜 맛있다 + 차돌 짬뽕
# 4655         4655             7.0              0.9900  짜장 떡볶이 + 떡볶이 맛있다
# 4656         4656             7.0              0.9898  짜장 떡볶이 + 떡볶이 맛있다
#
#                                         Keywords            지점명     유저  \
# 0      탕수육, 짜장, 고기, 없다, 간짜장, 짬뽕, 많다, 그냥, 아쉽다, 불어       상하이-인덕원점  gu**님
# 1       탕수육, 소스, 짬뽕, 좋다, 짜장면, 짜장, 바삭, 조금, 가지, 진짜       상하이-인덕원점  p2**님
# 2           , 시간, 보통, 짜장, 불어, 좋다, 전화, 예상, 짬뽕, 아이       상하이-인덕원점  ch**님
# 3       탕수육, 소스, 짬뽕, 좋다, 짜장면, 짜장, 바삭, 조금, 가지, 진짜       상하이-인덕원점  so**님
# 4      배달, 양도, 많다, 빠르다, 좋다, 빨르다, 배송, 괜찮다, 진짜, 시간       상하이-인덕원점  py**님
# ...                                          ...            ...    ...
# 4652   기분, 사람, 그냥, 먹기, 쿠폰, 그렇다, 나쁘다, 금방, 힘들다, 양파  매운국물방앗간떡볶이-본점     손님
# 4653   배달, 양도, 많다, 빠르다, 좋다, 빨르다, 배송, 괜찮다, 진짜, 시간  매운국물방앗간떡볶이-본점  u2**님
# 4654  짜장, 굿굿, 간짜장, 단골, 중국음식, 차돌, 진짜, 짬뽕, 최고, 떡볶이  매운국물방앗간떡볶이-본점  u2**님
# 4655   떡볶이, 단계, 짜장, 맵다, 꽃빵, 연유, 돈까스, 이벤트, 리뷰, 처음  매운국물방앗간떡볶이-본점     손님
# 4656   떡볶이, 단계, 짜장, 맵다, 꽃빵, 연유, 돈까스, 이벤트, 리뷰, 처음  매운국물방앗간떡볶이-본점  eu**님
#
#                                                      메뉴  \
# 0                   세트1（등심탕수육＋짜장1＋만두）/1(곱빼기 추가(곱빼기 추가))
# 1                                   세트1（등심탕수육＋짜장1＋만두）/1
# 2                            삼선짬뽕/1,세트1（등심탕수육＋짜장1＋만두）/1
# 3            짜장/1(곱빼기 추가(곱빼기 추가)),간짜장/2(곱빼기 추가(곱빼기 추가))
# 4             짜장/1(곱빼기 추가(곱빼기 추가)),짬뽕/1(곱빼기 추가(곱빼기 추가))
# ...                                                 ...
# 4652  치킨마요 컵밥세트 （떡볶이＋치킨마요컵밥＋순대＋쿨피스） /1(떡볶이 선택(짜장),매운...
# 4653  둘이서세트（떡볶이1~2人＋모듬튀김＋고로케2개）/1(떡볶이 선택(짜장),매운맛 선택(...
# 4654  둘이서세트（떡볶이1~2人＋모듬튀김＋고로케2개）/1(떡볶이 선택(짜장),매운맛 선택(...
# 4655  돈튀김 떡볶이/1(떡볶이 선택(짜장),매운맛 선택(1단계 맛있게매콤한맛),떡 ,오뎅...
# 4656  돈까스 컵밥세트（떡볶이＋돈까스컵밥＋순대＋쿨피스）/1(떡볶이 선택(짜장),매운맛 선택...
#
#                                                      리뷰  총점  맛  양  배달  \
# 0     집 가까운 중화요리집 많지만 굳이 비오는 날에 주문해서 죄송한데 아이들이 넘 맛있어...   5  5  5   5
# 1                                          항상맛있게 잘먹었습니다   5  5  5   5
# 2                                          감사합니다 잘먹었습니다   5  5  5   5
# 3           간짜장 딱 간도 맞고 면도 좋고 맛있게 잘먹었습니다 군만두 서비스도 좋아요     5  5  5   5
# 4                                           양도 많고 맛있어요    5  5  5   5
# ...                                                 ...  .. .. ..  ..
# 4652  떡이랑 오뎅이 너무안집혀져서 좀 먹기 힘들었는데 금방 배도차고맛있었어요 쿨피스 살얼...   4  5  5   3
# 4653                        빠르고 양많고 맛있고  박자가 다 아주 좋아요     5  5  5   5
# 4654                        지금까지 먹어본 짜장떡볶이 중에 제일 맛있어요     5  5  5   5
# 4655  완전 짜장으로 만든 떡볶이인줄 알았는데   짜장맛이 강하지 않고 잘 어울려요   단...   5  5  5   5
# 4656               아이랑같이먹었는데 돈까스덮밥을잘먹드라구요 순대도 떡볶이도다맜있어요   5  5  5   5
#
#                 시간
# 0            2시간 전
# 1           15시간 전
# 2               어제
# 3             4일 전
# 4             5일 전
# ...            ...
# 4652   2020년 3월 6일
# 4653   2020년 1월 2일
# 4654  2019년 8월 31일
# 4655  2019년 8월 12일
# 4656  2019년 7월 10일
#
# [4657 rows x 14 columns]

# %%
# 토픽별 리뷰수
element_count = {}
for row in df_topic_review.iloc:
    element_count.setdefault(row['Dominant_Topic'],0)
    element_count[row['Dominant_Topic']]+=1

# 토픽별 총점 합계
topic_total = {}
for row in df_topic_review.iloc:
    topic_total.setdefault(row['Dominant_Topic'],0)
    topic_total[row['Dominant_Topic']]+=row['총점']

# 토픽별 평균 총점    
for topic in topic_total:
    topic_total[topic] = topic_total[topic] / element_count[topic]
topic_total


# 평균 별점 순으로 정렬
sdict= sorted(topic_total.items(), key= lambda x : x[1],reverse = True)
sdict
# Out:
# [(8.0, 4.877358490566038),
#  (9.0, 4.858695652173913),
#  (13.0, 4.857142857142857),
#  (1.0, 4.848484848484849),
#  (7.0, 4.8108108108108105),
#  (16.0, 4.8),
#  (10.0, 4.780952380952381),
#  (15.0, 4.7560975609756095),
#  (4.0, 4.746543778801843),
#  (17.0, 4.711428571428572),
#  (14.0, 4.6421319796954315),
#  (6.0, 4.362068965517241),
#  (0.0, 4.23574144486692),
#  (11.0, 4.153846153846154),
#  (3.0, 3.9190600522193213),
#  (2.0, 3.8333333333333335),
#  (12.0, 3.825870646766169),
#  (5.0, 3.6785714285714284)]

# %%
result = pd.DataFrame()
for i in range(3):
    topic = int(sdict[i][0])
    score = round(sdict[i][1],4)
    res = optimal_model.get_topic_words(topic, top_n=10)
    label = labels_per_topic[topic]
    keywords = ', '.join(w for w, p in res)
    result = result.append(pd.Series([topic, label,keywords, score]), ignore_index=True)
result.columns = ['Topic_num', 'Topic_name','Keywords','Score']
# Out:
#    Topic_num         Topic_name                                    Keywords  \
# 0        8.0     최고 최고 + 탕수육 소스    최고, 중국집, 중식, 제일, 동네, 주문, 맛집, 북경, 상하이, 단골
# 1        9.0     진짜 맛있다 + 차돌 짬뽕  짜장, 굿굿, 간짜장, 단골, 중국음식, 차돌, 진짜, 짬뽕, 최고, 떡볶이
# 2       13.0  깔끔하다 맛있다 + 맛있다 자주  깔끔하다, 자주, 포장, 번창, 주문, 이용, 쟁반짜장, 중식, 좋다, 다시
#
#     Score
# 0  4.8774
# 1  4.8587
# 2  4.8571
